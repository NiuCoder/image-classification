# %% [markdown]
# # 图像分类
#
# 在此项目中，你将对 [CIFAR-10 数据集](https://www.cs.toronto.edu/~kriz/cifar.html) 中的图片进行分类。该数据集包含飞机、猫狗和其他物体。你需要预处理这些图片，然后用所有样本训练一个卷积神经网络。图片需要标准化（normalized），标签需要采用 one-hot 编码。你需要应用所学的知识构建卷积的、最大池化（max pooling）、丢弃（dropout）和完全连接（fully connected）的层。最后，你需要在样本图片上看到神经网络的预测结果。
#
#
# ## 获取数据
#
# 请运行以下单元，以下载 [CIFAR-10 数据集（Python版）](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz)。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [04:37, 614kB/s]
# All files found!

# %% [markdown]
# ## 探索数据
#
# 该数据集分成了几部分／批次（batches），以免你的机器在计算时内存不足。CIFAR-10 数据集包含 5 个部分，名称分别为 `data_batch_1`、`data_batch_2`，以此类推。每个部分都包含以下某个类别的标签和图片：
#
# * 飞机
# * 汽车
# * 鸟类
# * 猫
# * 鹿
# * 狗
# * 青蛙
# * 马
# * 船只
# * 卡车
#
# 了解数据集也是对数据进行预测的必经步骤。你可以通过更改 `batch_id` 和 `sample_id` 探索下面的代码单元。`batch_id` 是数据集一个部分的 ID（1 到 5）。`sample_id` 是该部分中图片和标签对（label pair）的 ID。
#
# 问问你自己：“可能的标签有哪些？”、“图片数据的值范围是多少？”、“标签是按顺序排列，还是随机排列的？”。思考类似的问题，有助于你预处理数据，并使预测结果更准确。

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# /home/ubuntu/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py:278: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## 实现预处理函数
#
# ### 标准化
#
# 在下面的单元中，实现 `normalize` 函数，传入图片数据 `x`，并返回标准化 Numpy 数组。值应该在 0 到 1 的范围内（含 0 和 1）。返回对象应该和 `x` 的形状一样。

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return x/255


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot 编码
#
# 和之前的代码单元一样，你将为预处理实现一个函数。这次，你将实现 `one_hot_encode` 函数。输入，也就是 `x`，是一个标签列表。实现该函数，以返回为 one_hot 编码的 Numpy 数组的标签列表。标签的可能值为 0 到 9。每次调用 `one_hot_encode` 时，对于每个值，one_hot 编码函数应该返回相同的编码。确保将编码映射保存到该函数外面。
#
# 提示：不要重复发明轮子。

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    res = np.zeros((len(x),10))
    for i in range(len(x)):
        res[i,x[i]] = 1
    return res


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### 随机化数据
#
# 之前探索数据时，你已经了解到，样本的顺序是随机的。再随机化一次也不会有什么关系，但是对于这个数据集没有必要。

# %% [markdown]
# ## 预处理所有数据并保存
#
# 运行下方的代码单元，将预处理所有 CIFAR-10 数据，并保存到文件中。下面的代码还使用了 10% 的训练数据，用来验证。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # 检查点
#
# 这是你的第一个检查点。如果你什么时候决定再回到该记事本，或需要重新启动该记事本，你可以从这里开始。预处理的数据已保存到本地。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## 构建网络
#
# 对于该神经网络，你需要将每层都构建为一个函数。你看到的大部分代码都位于函数外面。要更全面地测试你的代码，我们需要你将每层放入一个函数中。这样使我们能够提供更好的反馈，并使用我们的统一测试检测简单的错误，然后再提交项目。
#
# >**注意**：如果你觉得每周很难抽出足够的时间学习这门课程，我们为此项目提供了一个小捷径。对于接下来的几个问题，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 程序包中的类来构建每个层级，但是“卷积和最大池化层级”部分的层级除外。TF Layers 和 Keras 及 TFLearn 层级类似，因此很容易学会。
#
# >但是，如果你想充分利用这门课程，请尝试自己解决所有问题，不使用 TF Layers 程序包中的任何类。你依然可以使用其他程序包中的类，这些类和你在 TF Layers 中的类名称是一样的！例如，你可以使用 TF Neural Network 版本的 `conv2d` 类 [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d)，而不是 TF Layers 版本的 `conv2d` 类 [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d)。
#
# 我们开始吧！
#
#
# ### 输入
#
# 神经网络需要读取图片数据、one-hot 编码标签和丢弃保留概率（dropout keep probability）。请实现以下函数：
#
# * 实现 `neural_net_image_input`
#  * 返回 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * 使用 `image_shape` 设置形状，部分大小设为 `None`
#  * 使用 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) 中的 TensorFlow `name` 参数对 TensorFlow 占位符 "x" 命名
# * 实现 `neural_net_label_input`
#  * 返回 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * 使用 `n_classes` 设置形状，部分大小设为 `None`
#  * 使用 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) 中的 TensorFlow `name` 参数对 TensorFlow 占位符 "y" 命名
# * 实现 `neural_net_keep_prob_input`
#  * 返回 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)，用于丢弃保留概率
#  * 使用 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) 中的 TensorFlow `name` 参数对 TensorFlow 占位符 "keep_prob" 命名
#
# 这些名称将在项目结束时，用于加载保存的模型。
#
# 注意：TensorFlow 中的 `None` 表示形状可以是动态大小。

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    x = tf.placeholder("float",[None,image_shape[0],image_shape[1],image_shape[2]],"x")
    return x


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    y = tf.placeholder("float",[None,n_classes],"y")
    return y


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    keep_prob = tf.placeholder("float",None,"keep_prob")
    return keep_prob


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### 卷积和最大池化层
#
# 卷积层级适合处理图片。对于此代码单元，你应该实现函数 `conv2d_maxpool` 以便应用卷积然后进行最大池化：
#
# * 使用 `conv_ksize`、`conv_num_outputs` 和 `x_tensor` 的形状创建权重（weight）和偏置（bias）。
# * 使用权重和 `conv_strides` 对 `x_tensor` 应用卷积。
#  * 建议使用我们建议的间距（padding），当然也可以使用任何其他间距。
# * 添加偏置
# * 向卷积中添加非线性激活（nonlinear activation）
# * 使用 `pool_ksize` 和 `pool_strides` 应用最大池化
#  * 建议使用我们建议的间距（padding），当然也可以使用任何其他间距。
#
# **注意**：对于**此层**，**请勿使用** [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers)，但是仍然可以使用 TensorFlow 的 [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) 包。对于所有**其他层**，你依然可以使用快捷方法。

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    shape = x_tensor.shape
    weight = tf.Variable(tf.truncated_normal(
                [conv_ksize[0],conv_ksize[1],tf.cast(shape[3],tf.int32),conv_num_outputs],
                mean=0,
                stddev=0.05,
                dtype=tf.float32
                ))
    bias = tf.Variable(tf.random_normal(
                [conv_num_outputs],
                mean=0,
                stddev=0.05,
                dtype=tf.float32
                ))
    conv_layer = tf.nn.conv2d(x_tensor,weight,[1,conv_strides[0],conv_strides[1],1],padding="SAME")
    conv_layer = tf.nn.bias_add(conv_layer,bias)
    conv_layer = tf.nn.relu(conv_layer)
    conv_layer = tf.nn.max_pool(
            conv_layer,
            [1,pool_ksize[0],pool_ksize[1],1],
            [1,pool_strides[0],pool_strides[1],1],
            padding="SAME")
    return conv_layer 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### 扁平化层
#
# 实现 `flatten` 函数，将 `x_tensor` 的维度从四维张量（4-D tensor）变成二维张量。输出应该是形状（*部分大小（Batch Size）*，*扁平化图片大小（Flattened Image Size）*）。快捷方法：对于此层，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的类。如果你想要更大挑战，可以仅使用其他 TensorFlow 程序包。

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    y = tf.contrib.layers.flatten(x_tensor)
    return y


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### 全连接层
#
# 实现 `fully_conn` 函数，以向 `x_tensor` 应用完全连接的层级，形状为（*部分大小（Batch Size）*，*num_outputs*）。快捷方法：对于此层，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的类。如果你想要更大挑战，可以仅使用其他 TensorFlow 程序包。

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
#     y = tf.contrib.layers.fully_connected(x_tensor,num_outputs)
    y = tf.layers.dense(inputs=x_tensor,units=num_outputs,activation=tf.nn.softmax)
    return y


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### 输出层
#
# 实现 `output` 函数，向 x_tensor 应用完全连接的层级，形状为（*部分大小（Batch Size）*，*num_outputs*）。快捷方法：对于此层，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的类。如果你想要更大挑战，可以仅使用其他 TensorFlow 程序包。
#
# **注意**：该层级不应应用 Activation、softmax 或交叉熵（cross entropy）。

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    y = tf.layers.dense(inputs=x_tensor,units=num_outputs)
    return y


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### 创建卷积模型
#
# 实现函数 `conv_net`， 创建卷积神经网络模型。该函数传入一批图片 `x`，并输出对数（logits）。使用你在上方创建的层创建此模型：
#
# * 应用 1、2 或 3 个卷积和最大池化层（Convolution and Max Pool layers）
# * 应用一个扁平层（Flatten Layer）
# * 应用 1、2 或 3 个完全连接层（Fully Connected Layers）
# * 应用一个输出层（Output Layer）
# * 返回输出
# * 使用 `keep_prob` 向模型中的一个或多个层应用 [TensorFlow 的 Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout)

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv_layer1 = conv2d_maxpool(x,64,[2,2],[1,1],[2,2],[2,2])
#     dropout1 = tf.layers.dropout(inputs=conv_layer1,rate=keep_prob)
    conv_layer2 = conv2d_maxpool(conv_layer1,256,[2,2],[1,1],[2,2],[2,2])
#     dropout2 = tf.layers.dropout(inputs=conv_layer2,rate=keep_prob)
#     conv_layer3 = conv2d_maxpool(dropout2,128,[3,3],[1,1],[2,2],[2,2])
#     dropout3 = tf.layers.dropout(inputs=conv_layer3,rate=0.2)
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flat_layer = flatten(conv_layer2)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fc_layer1 = fully_conn(flat_layer,512)
#     dropout4 = tf.layers.dropout(inputs=fc_layer1,rate=keep_prob)
    fc_layer2 = fully_conn(fc_layer1,256)
    dropout5 = tf.layers.dropout(inputs=fc_layer2,rate=keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    output_layer = output(dropout5,10)
    
    # TODO: return output
    return output_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## 训练神经网络
#
# ### 单次优化
#
# 实现函数 `train_neural_network` 以进行单次优化（single optimization）。该优化应该使用 `optimizer` 优化 `session`，其中 `feed_dict` 具有以下参数：
#
# * `x` 表示图片输入
# * `y` 表示标签
# * `keep_prob` 表示丢弃的保留率
#
# 每个部分都会调用该函数，所以 `tf.global_variables_initializer()` 已经被调用。
#
# 注意：不需要返回任何内容。该函数只是用来优化神经网络。

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer,feed_dict={x:feature_batch,y:label_batch,keep_prob:keep_probability})
    pass


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### 显示数据
#
# 实现函数 `print_stats` 以输出损失和验证准确率。使用全局变量 `valid_features` 和 `valid_labels` 计算验证准确率。使用保留率 `1.0` 计算损失和验证准确率（loss and validation accuracy）。

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    c = session.run(cost,feed_dict={x:feature_batch,y:label_batch,keep_prob:0.1})
    print("cost:",c)
    accu = session.run(accuracy,feed_dict={x:valid_features,y:valid_labels})
    print("Accuracy:",accu)
    pass

# %% [markdown]
# ### 超参数
#
# 调试以下超参数：
# * 设置 `epochs` 表示神经网络停止学习或开始过拟合的迭代次数
# * 设置 `batch_size`，表示机器内存允许的部分最大体积。大部分人设为以下常见内存大小：
#
#  * 64
#  * 128
#  * 256
#  * ...
# * 设置 `keep_probability` 表示使用丢弃时保留节点的概率

# %%
# TODO: Tune Parameters
epochs = 200
batch_size = 64
keep_probability = 0.5

# %% [markdown]
# ### 在单个 CIFAR-10 部分上训练
#
# 我们先用单个部分，而不是用所有的 CIFAR-10 批次训练神经网络。这样可以节省时间，并对模型进行迭代，以提高准确率。最终验证准确率达到 50% 或以上之后，在下一部分对所有数据运行模型。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  cost: 2.30278
# Accuracy: 0.1516
# Epoch  2, CIFAR-10 Batch 1:  cost: 2.29731
# Accuracy: 0.1794
# Epoch  3, CIFAR-10 Batch 1:  cost: 2.28149
# Accuracy: 0.1838
# Epoch  4, CIFAR-10 Batch 1:  cost: 2.24139
# Accuracy: 0.1808
# Epoch  5, CIFAR-10 Batch 1:  cost: 2.22365
# Accuracy: 0.1876
# Epoch  6, CIFAR-10 Batch 1:  cost: 2.1344
# Accuracy: 0.1878
# Epoch  7, CIFAR-10 Batch 1:  cost: 2.1066
# Accuracy: 0.1872
# Epoch  8, CIFAR-10 Batch 1:  cost: 2.06187
# Accuracy: 0.1874
# Epoch  9, CIFAR-10 Batch 1:  cost: 2.09216
# Accuracy: 0.1898
# Epoch 10, CIFAR-10 Batch 1:  cost: 2.09518
# Accuracy: 0.184
# Epoch 11, CIFAR-10 Batch 1:  cost: 2.0941
# Accuracy: 0.1888
# Epoch 12, CIFAR-10 Batch 1:  cost: 2.10664
# Accuracy: 0.1916
# Epoch 13, CIFAR-10 Batch 1:  cost: 2.07797
# Accuracy: 0.1852
# Epoch 14, CIFAR-10 Batch 1:  cost: 2.08994
# Accuracy: 0.1906
# Epoch 15, CIFAR-10 Batch 1:  cost: 2.0603
# Accuracy: 0.192
# Epoch 16, CIFAR-10 Batch 1:  cost: 2.06081
# Accuracy: 0.1944
# Epoch 17, CIFAR-10 Batch 1:  cost: 2.05375
# Accuracy: 0.1956
# Epoch 18, CIFAR-10 Batch 1:  cost: 2.04315
# Accuracy: 0.1974
# Epoch 19, CIFAR-10 Batch 1:  cost: 1.97221
# Accuracy: 0.2032
# Epoch 20, CIFAR-10 Batch 1:  cost: 1.93795
# Accuracy: 0.2026
# Epoch 21, CIFAR-10 Batch 1:  cost: 1.93687
# Accuracy: 0.2044
# Epoch 22, CIFAR-10 Batch 1:  cost: 1.95364
# Accuracy: 0.2184
# Epoch 23, CIFAR-10 Batch 1:  cost: 1.93671
# Accuracy: 0.2174
# Epoch 24, CIFAR-10 Batch 1:  cost: 1.92801
# Accuracy: 0.2302
# Epoch 25, CIFAR-10 Batch 1:  cost: 1.90041
# Accuracy: 0.238
# Epoch 26, CIFAR-10 Batch 1:  cost: 1.89203
# Accuracy: 0.238
# Epoch 27, CIFAR-10 Batch 1:  cost: 1.8811
# Accuracy: 0.2444
# Epoch 28, CIFAR-10 Batch 1:  cost: 1.86384
# Accuracy: 0.2486
# Epoch 29, CIFAR-10 Batch 1:  cost: 1.82055
# Accuracy: 0.2568
# Epoch 30, CIFAR-10 Batch 1:  cost: 1.8094
# Accuracy: 0.2596
# Epoch 31, CIFAR-10 Batch 1:  cost: 1.79685
# Accuracy: 0.2684
# Epoch 32, CIFAR-10 Batch 1:  cost: 1.77429
# Accuracy: 0.2692
# Epoch 33, CIFAR-10 Batch 1:  cost: 1.74899
# Accuracy: 0.2824
# Epoch 34, CIFAR-10 Batch 1:  cost: 1.7337
# Accuracy: 0.298
# Epoch 35, CIFAR-10 Batch 1:  cost: 1.69817
# Accuracy: 0.3094
# Epoch 36, CIFAR-10 Batch 1:  cost: 1.68337
# Accuracy: 0.314
# Epoch 37, CIFAR-10 Batch 1:  cost: 1.69387
# Accuracy: 0.3178
# Epoch 38, CIFAR-10 Batch 1:  cost: 1.66961
# Accuracy: 0.3318
# Epoch 39, CIFAR-10 Batch 1:  cost: 1.62876
# Accuracy: 0.3404
# Epoch 40, CIFAR-10 Batch 1:  cost: 1.56342
# Accuracy: 0.3444
# Epoch 41, CIFAR-10 Batch 1:  cost: 1.47713
# Accuracy: 0.3544
# Epoch 42, CIFAR-10 Batch 1:  cost: 1.46891
# Accuracy: 0.363
# Epoch 43, CIFAR-10 Batch 1:  cost: 1.46236
# Accuracy: 0.3612
# Epoch 44, CIFAR-10 Batch 1:  cost: 1.43076
# Accuracy: 0.362
# Epoch 45, CIFAR-10 Batch 1:  cost: 1.37735
# Accuracy: 0.3844
# Epoch 46, CIFAR-10 Batch 1:  cost: 1.42377
# Accuracy: 0.3826
# Epoch 47, CIFAR-10 Batch 1:  cost: 1.36391
# Accuracy: 0.3846
# Epoch 48, CIFAR-10 Batch 1:  cost: 1.3559
# Accuracy: 0.3758
# Epoch 49, CIFAR-10 Batch 1:  cost: 1.35695
# Accuracy: 0.3846
# Epoch 50, CIFAR-10 Batch 1:  cost: 1.34757
# Accuracy: 0.3932
# Epoch 51, CIFAR-10 Batch 1:  cost: 1.39456
# Accuracy: 0.3942
# Epoch 52, CIFAR-10 Batch 1:  cost: 1.37279
# Accuracy: 0.3992
# Epoch 53, CIFAR-10 Batch 1:  cost: 1.37747
# Accuracy: 0.4016
# Epoch 54, CIFAR-10 Batch 1:  cost: 1.3421
# Accuracy: 0.4016
# Epoch 55, CIFAR-10 Batch 1:  cost: 1.34892
# Accuracy: 0.4012
# Epoch 56, CIFAR-10 Batch 1:  cost: 1.34874
# Accuracy: 0.3984
# Epoch 57, CIFAR-10 Batch 1:  cost: 1.31425
# Accuracy: 0.4026
# Epoch 58, CIFAR-10 Batch 1:  cost: 1.33732
# Accuracy: 0.4054
# Epoch 59, CIFAR-10 Batch 1:  cost: 1.34867
# Accuracy: 0.4068
# Epoch 60, CIFAR-10 Batch 1:  cost: 1.29895
# Accuracy: 0.4038
# Epoch 61, CIFAR-10 Batch 1:  cost: 1.31338
# Accuracy: 0.4122
# Epoch 62, CIFAR-10 Batch 1:  cost: 1.25576
# Accuracy: 0.424
# Epoch 63, CIFAR-10 Batch 1:  cost: 1.28434
# Accuracy: 0.4224
# Epoch 64, CIFAR-10 Batch 1:  cost: 1.33279
# Accuracy: 0.4248
# Epoch 65, CIFAR-10 Batch 1:  cost: 1.25006
# Accuracy: 0.4168
# Epoch 66, CIFAR-10 Batch 1:  cost: 1.25371
# Accuracy: 0.4208
# Epoch 67, CIFAR-10 Batch 1:  cost: 1.23655
# Accuracy: 0.4236
# Epoch 68, CIFAR-10 Batch 1:  cost: 1.21911
# Accuracy: 0.426
# Epoch 69, CIFAR-10 Batch 1:  cost: 1.21251
# Accuracy: 0.4204
# Epoch 70, CIFAR-10 Batch 1:  cost: 1.19675
# Accuracy: 0.4206
# Epoch 71, CIFAR-10 Batch 1:  cost: 1.24739
# Accuracy: 0.4228
# Epoch 72, CIFAR-10 Batch 1:  cost: 1.13273
# Accuracy: 0.4222
# Epoch 73, CIFAR-10 Batch 1:  cost: 1.10191
# Accuracy: 0.4178
# Epoch 74, CIFAR-10 Batch 1:  cost: 1.13476
# Accuracy: 0.424
# Epoch 75, CIFAR-10 Batch 1:  cost: 1.09519
# Accuracy: 0.4258
# Epoch 76, CIFAR-10 Batch 1:  cost: 1.07413
# Accuracy: 0.4188
# Epoch 77, CIFAR-10 Batch 1:  cost: 1.03127
# Accuracy: 0.4184
# Epoch 78, CIFAR-10 Batch 1:  cost: 1.03956
# Accuracy: 0.4168
# Epoch 79, CIFAR-10 Batch 1:  cost: 1.01567
# Accuracy: 0.4226
# Epoch 80, CIFAR-10 Batch 1:  cost: 1.0253
# Accuracy: 0.4132
# Epoch 81, CIFAR-10 Batch 1:  cost: 1.02088
# Accuracy: 0.4238
# Epoch 82, CIFAR-10 Batch 1:  cost: 1.01529
# Accuracy: 0.4246
# Epoch 83, CIFAR-10 Batch 1:  cost: 0.989371
# Accuracy: 0.4238
# Epoch 84, CIFAR-10 Batch 1:  cost: 0.999057
# Accuracy: 0.4294
# Epoch 85, CIFAR-10 Batch 1:  cost: 0.997866
# Accuracy: 0.4322
# Epoch 86, CIFAR-10 Batch 1:  cost: 0.985016
# Accuracy: 0.4346
# Epoch 87, CIFAR-10 Batch 1:  cost: 0.90218
# Accuracy: 0.4234
# Epoch 88, CIFAR-10 Batch 1:  cost: 0.979602
# Accuracy: 0.4368
# Epoch 89, CIFAR-10 Batch 1:  cost: 0.990622
# Accuracy: 0.4206
# Epoch 90, CIFAR-10 Batch 1:  cost: 0.990207
# Accuracy: 0.4284
# Epoch 91, CIFAR-10 Batch 1:  cost: 0.984374
# Accuracy: 0.4346
# Epoch 92, CIFAR-10 Batch 1:  cost: 0.97179
# Accuracy: 0.4276
# Epoch 93, CIFAR-10 Batch 1:  cost: 0.934533
# Accuracy: 0.4286
# Epoch 94, CIFAR-10 Batch 1:  cost: 0.893313
# Accuracy: 0.4278
# Epoch 95, CIFAR-10 Batch 1:  cost: 0.886658
# Accuracy: 0.4286
# Epoch 96, CIFAR-10 Batch 1:  cost: 0.901333
# Accuracy: 0.4328
# Epoch 97, CIFAR-10 Batch 1:  cost: 0.877899
# Accuracy: 0.4216
# Epoch 98, CIFAR-10 Batch 1:  cost: 0.872531
# Accuracy: 0.4294
# Epoch 99, CIFAR-10 Batch 1:  cost: 0.878294
# Accuracy: 0.4364
# Epoch 100, CIFAR-10 Batch 1:  cost: 0.888447
# Accuracy: 0.4244
# Epoch 101, CIFAR-10 Batch 1:  cost: 0.887806
# Accuracy: 0.4296
# Epoch 102, CIFAR-10 Batch 1:  cost: 0.86969
# Accuracy: 0.4292
# Epoch 103, CIFAR-10 Batch 1:  cost: 0.869313
# Accuracy: 0.4194
# Epoch 104, CIFAR-10 Batch 1:  cost: 0.874206
# Accuracy: 0.4316
# Epoch 105, CIFAR-10 Batch 1:  cost: 0.863335
# Accuracy: 0.429
# Epoch 106, CIFAR-10 Batch 1:  cost: 0.863894
# Accuracy: 0.4228
# Epoch 107, CIFAR-10 Batch 1:  cost: 0.856616
# Accuracy: 0.4268
# Epoch 108, CIFAR-10 Batch 1:  cost: 0.85885
# Accuracy: 0.4298
# Epoch 109, CIFAR-10 Batch 1:  cost: 0.863105
# Accuracy: 0.4318
# Epoch 110, CIFAR-10 Batch 1:  cost: 0.860117
# Accuracy: 0.435
# Epoch 111, CIFAR-10 Batch 1:  cost: 0.860453
# Accuracy: 0.4222
# Epoch 112, CIFAR-10 Batch 1:  cost: 0.886556
# Accuracy: 0.4388
# Epoch 113, CIFAR-10 Batch 1:  cost: 0.871782
# Accuracy: 0.4264
# Epoch 114, CIFAR-10 Batch 1:  cost: 0.87994
# Accuracy: 0.4282
# Epoch 115, CIFAR-10 Batch 1:  cost: 0.855696
# Accuracy: 0.4372
# Epoch 116, CIFAR-10 Batch 1:  cost: 0.859605
# Accuracy: 0.4308
# Epoch 117, CIFAR-10 Batch 1:  cost: 0.857031
# Accuracy: 0.4316
# Epoch 118, CIFAR-10 Batch 1:  cost: 0.851784
# Accuracy: 0.4342
# Epoch 119, CIFAR-10 Batch 1:  cost: 0.855004
# Accuracy: 0.4316
# Epoch 120, CIFAR-10 Batch 1:  cost: 0.847309
# Accuracy: 0.4314
# Epoch 121, CIFAR-10 Batch 1:  cost: 0.851968
# Accuracy: 0.4326
# Epoch 122, CIFAR-10 Batch 1:  cost: 0.838962
# Accuracy: 0.4356
# Epoch 123, CIFAR-10 Batch 1:  cost: 0.834514
# Accuracy: 0.4312
# Epoch 124, CIFAR-10 Batch 1:  cost: 0.829741
# Accuracy: 0.4286
# Epoch 125, CIFAR-10 Batch 1:  cost: 0.828643
# Accuracy: 0.4346
# Epoch 126, CIFAR-10 Batch 1:  cost: 0.791209
# Accuracy: 0.4342
# Epoch 127, CIFAR-10 Batch 1:  cost: 0.788915
# Accuracy: 0.44
# Epoch 128, CIFAR-10 Batch 1:  cost: 0.784889
# Accuracy: 0.4404
# Epoch 129, CIFAR-10 Batch 1:  cost: 0.790583
# Accuracy: 0.4398
# Epoch 130, CIFAR-10 Batch 1:  cost: 0.790389
# Accuracy: 0.434
# Epoch 131, CIFAR-10 Batch 1:  cost: 0.771133
# Accuracy: 0.4396
# Epoch 132, CIFAR-10 Batch 1:  cost: 0.778978
# Accuracy: 0.436
# Epoch 133, CIFAR-10 Batch 1:  cost: 0.782562
# Accuracy: 0.4392
# Epoch 134, CIFAR-10 Batch 1:  cost: 0.77506
# Accuracy: 0.4324
# Epoch 135, CIFAR-10 Batch 1:  cost: 0.778779
# Accuracy: 0.436
# Epoch 136, CIFAR-10 Batch 1:  cost: 0.750301
# Accuracy: 0.4346
# Epoch 137, CIFAR-10 Batch 1:  cost: 0.815345
# Accuracy: 0.4452
# Epoch 138, CIFAR-10 Batch 1:  cost: 0.804048
# Accuracy: 0.4374
# Epoch 139, CIFAR-10 Batch 1:  cost: 0.769765
# Accuracy: 0.4426
# Epoch 140, CIFAR-10 Batch 1:  cost: 0.759265
# Accuracy: 0.4494
# Epoch 141, CIFAR-10 Batch 1:  cost: 0.770977
# Accuracy: 0.447
# Epoch 142, CIFAR-10 Batch 1:  cost: 0.751105
# Accuracy: 0.4482
# Epoch 143, CIFAR-10 Batch 1:  cost: 0.746301
# Accuracy: 0.4506
# Epoch 144, CIFAR-10 Batch 1:  cost: 0.711231
# Accuracy: 0.4552
# Epoch 145, CIFAR-10 Batch 1:  cost: 0.714127
# Accuracy: 0.4534
# Epoch 146, CIFAR-10 Batch 1:  cost: 0.72442
# Accuracy: 0.4546
# Epoch 147, CIFAR-10 Batch 1:  cost: 0.706378
# Accuracy: 0.447
# Epoch 148, CIFAR-10 Batch 1:  cost: 0.70943
# Accuracy: 0.4534
# Epoch 149, CIFAR-10 Batch 1:  cost: 0.714346
# Accuracy: 0.4518
# Epoch 150, CIFAR-10 Batch 1:  cost: 0.706874
# Accuracy: 0.4546
# Epoch 151, CIFAR-10 Batch 1:  cost: 0.70174
# Accuracy: 0.4588
# Epoch 152, CIFAR-10 Batch 1:  cost: 0.690744
# Accuracy: 0.4624
# Epoch 153, CIFAR-10 Batch 1:  cost: 0.690728
# Accuracy: 0.4542
# Epoch 154, CIFAR-10 Batch 1:  cost: 0.673309
# Accuracy: 0.4536
# Epoch 155, CIFAR-10 Batch 1:  cost: 0.676148
# Accuracy: 0.4588
# Epoch 156, CIFAR-10 Batch 1:  cost: 0.67302
# Accuracy: 0.4484
# Epoch 157, CIFAR-10 Batch 1:  cost: 0.663649
# Accuracy: 0.4526
# Epoch 158, CIFAR-10 Batch 1:  cost: 0.637244
# Accuracy: 0.4654
# Epoch 159, CIFAR-10 Batch 1:  cost: 0.621613
# Accuracy: 0.465
# Epoch 160, CIFAR-10 Batch 1:  cost: 0.610511
# Accuracy: 0.4784
# Epoch 161, CIFAR-10 Batch 1:  cost: 0.582298
# Accuracy: 0.4724
# Epoch 162, CIFAR-10 Batch 1:  cost: 0.572231
# Accuracy: 0.4792
# Epoch 163, CIFAR-10 Batch 1:  cost: 0.569951
# Accuracy: 0.4812
# Epoch 164, CIFAR-10 Batch 1:  cost: 0.58056
# Accuracy: 0.4912
# Epoch 165, CIFAR-10 Batch 1:  cost: 0.50425
# Accuracy: 0.49
# Epoch 166, CIFAR-10 Batch 1:  cost: 0.531388
# Accuracy: 0.4986
# Epoch 167, CIFAR-10 Batch 1:  cost: 0.482793
# Accuracy: 0.5054
# Epoch 168, CIFAR-10 Batch 1:  cost: 0.449974
# Accuracy: 0.4884
# Epoch 169, CIFAR-10 Batch 1:  cost: 0.468744
# Accuracy: 0.495
# Epoch 170, CIFAR-10 Batch 1:  cost: 0.429575
# Accuracy: 0.4942
# Epoch 171, CIFAR-10 Batch 1:  cost: 0.429286
# Accuracy: 0.4918
# Epoch 172, CIFAR-10 Batch 1:  cost: 0.43136
# Accuracy: 0.4948
# Epoch 173, CIFAR-10 Batch 1:  cost: 0.461147
# Accuracy: 0.5118
# Epoch 174, CIFAR-10 Batch 1:  cost: 0.416112
# Accuracy: 0.5062
# Epoch 175, CIFAR-10 Batch 1:  cost: 0.414583
# Accuracy: 0.5004
# Epoch 176, CIFAR-10 Batch 1:  cost: 0.427788
# Accuracy: 0.5062
# Epoch 177, CIFAR-10 Batch 1:  cost: 0.423012
# Accuracy: 0.5014
# Epoch 178, CIFAR-10 Batch 1:  cost: 0.440905
# Accuracy: 0.5022
# Epoch 179, CIFAR-10 Batch 1:  cost: 0.371357
# Accuracy: 0.5056
# Epoch 180, CIFAR-10 Batch 1:  cost: 0.376676
# Accuracy: 0.5062
# Epoch 181, CIFAR-10 Batch 1:  cost: 0.364821
# Accuracy: 0.5014
# Epoch 182, CIFAR-10 Batch 1:  cost: 0.324739
# Accuracy: 0.4948
# Epoch 183, CIFAR-10 Batch 1:  cost: 0.333776
# Accuracy: 0.5006
# Epoch 184, CIFAR-10 Batch 1:  cost: 0.343152
# Accuracy: 0.5048
# Epoch 185, CIFAR-10 Batch 1:  cost: 0.323858
# Accuracy: 0.5066
# Epoch 186, CIFAR-10 Batch 1:  cost: 0.310637
# Accuracy: 0.5138
# Epoch 187, CIFAR-10 Batch 1:  cost: 0.312589
# Accuracy: 0.5092
# Epoch 188, CIFAR-10 Batch 1:  cost: 0.30058
# Accuracy: 0.5088
# Epoch 189, CIFAR-10 Batch 1:  cost: 0.289259
# Accuracy: 0.511
# Epoch 190, CIFAR-10 Batch 1:  cost: 0.297024
# Accuracy: 0.5112
# Epoch 191, CIFAR-10 Batch 1:  cost: 0.296123
# Accuracy: 0.5086
# Epoch 192, CIFAR-10 Batch 1:  cost: 0.307641
# Accuracy: 0.5146
# Epoch 193, CIFAR-10 Batch 1:  cost: 0.275135
# Accuracy: 0.5006
# Epoch 194, CIFAR-10 Batch 1:  cost: 0.264857
# Accuracy: 0.5036
# Epoch 195, CIFAR-10 Batch 1:  cost: 0.240709
# Accuracy: 0.5106
# Epoch 196, CIFAR-10 Batch 1:  cost: 0.237435
# Accuracy: 0.5116
# Epoch 197, CIFAR-10 Batch 1:  cost: 0.230974
# Accuracy: 0.5152
# Epoch 198, CIFAR-10 Batch 1:  cost: 0.24382
# Accuracy: 0.5084
# Epoch 199, CIFAR-10 Batch 1:  cost: 0.240655
# Accuracy: 0.515
# Epoch 200, CIFAR-10 Batch 1:  cost: 0.242291
# Accuracy: 0.5104

# %% [markdown]
# ### 完全训练模型
#
# 现在，单个 CIFAR-10 部分的准确率已经不错了，试试所有五个部分吧。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  cost: 2.30209
# Accuracy: 0.1624
# Epoch  1, CIFAR-10 Batch 2:  cost: 2.29563
# Accuracy: 0.1864
# Epoch  1, CIFAR-10 Batch 3:  cost: 2.25929
# Accuracy: 0.1806
# Epoch  1, CIFAR-10 Batch 4:  cost: 2.21564
# Accuracy: 0.1884
# Epoch  1, CIFAR-10 Batch 5:  cost: 2.17462
# Accuracy: 0.1778
# Epoch  2, CIFAR-10 Batch 1:  cost: 2.19118
# Accuracy: 0.1882
# Epoch  2, CIFAR-10 Batch 2:  cost: 2.1226
# Accuracy: 0.1764
# Epoch  2, CIFAR-10 Batch 3:  cost: 1.88436
# Accuracy: 0.1758
# Epoch  2, CIFAR-10 Batch 4:  cost: 2.03948
# Accuracy: 0.193
# Epoch  2, CIFAR-10 Batch 5:  cost: 1.95845
# Accuracy: 0.1848
# Epoch  3, CIFAR-10 Batch 1:  cost: 2.15554
# Accuracy: 0.191
# Epoch  3, CIFAR-10 Batch 2:  cost: 2.03751
# Accuracy: 0.1956
# Epoch  3, CIFAR-10 Batch 3:  cost: 1.7545
# Accuracy: 0.1932
# Epoch  3, CIFAR-10 Batch 4:  cost: 1.91025
# Accuracy: 0.202
# Epoch  3, CIFAR-10 Batch 5:  cost: 1.89364
# Accuracy: 0.2038
# Epoch  4, CIFAR-10 Batch 1:  cost: 2.03498
# Accuracy: 0.2258
# Epoch  4, CIFAR-10 Batch 2:  cost: 2.00178
# Accuracy: 0.2158
# Epoch  4, CIFAR-10 Batch 3:  cost: 1.71312
# Accuracy: 0.2098
# Epoch  4, CIFAR-10 Batch 4:  cost: 1.8797
# Accuracy: 0.231
# Epoch  4, CIFAR-10 Batch 5:  cost: 1.80093
# Accuracy: 0.2308
# Epoch  5, CIFAR-10 Batch 1:  cost: 2.04074
# Accuracy: 0.2354
# Epoch  5, CIFAR-10 Batch 2:  cost: 1.96674
# Accuracy: 0.2306
# Epoch  5, CIFAR-10 Batch 3:  cost: 1.67996
# Accuracy: 0.2422
# Epoch  5, CIFAR-10 Batch 4:  cost: 1.83709
# Accuracy: 0.2604
# Epoch  5, CIFAR-10 Batch 5:  cost: 1.73341
# Accuracy: 0.2648
# Epoch  6, CIFAR-10 Batch 1:  cost: 1.85277
# Accuracy: 0.2714
# Epoch  6, CIFAR-10 Batch 2:  cost: 1.94799
# Accuracy: 0.2768
# Epoch  6, CIFAR-10 Batch 3:  cost: 1.56758
# Accuracy: 0.2718
# Epoch  6, CIFAR-10 Batch 4:  cost: 1.72957
# Accuracy: 0.2802
# Epoch  6, CIFAR-10 Batch 5:  cost: 1.60602
# Accuracy: 0.2728
# Epoch  7, CIFAR-10 Batch 1:  cost: 1.74498
# Accuracy: 0.29
# Epoch  7, CIFAR-10 Batch 2:  cost: 1.86046
# Accuracy: 0.2782
# Epoch  7, CIFAR-10 Batch 3:  cost: 1.49196
# Accuracy: 0.282
# Epoch  7, CIFAR-10 Batch 4:  cost: 1.65718
# Accuracy: 0.3118
# Epoch  7, CIFAR-10 Batch 5:  cost: 1.5283
# Accuracy: 0.3048
# Epoch  8, CIFAR-10 Batch 1:  cost: 1.81917
# Accuracy: 0.321
# Epoch  8, CIFAR-10 Batch 2:  cost: 1.69119
# Accuracy: 0.3292
# Epoch  8, CIFAR-10 Batch 3:  cost: 1.45503
# Accuracy: 0.3222
# Epoch  8, CIFAR-10 Batch 4:  cost: 1.64555
# Accuracy: 0.332
# Epoch  8, CIFAR-10 Batch 5:  cost: 1.42708
# Accuracy: 0.3368
# Epoch  9, CIFAR-10 Batch 1:  cost: 1.66384
# Accuracy: 0.3488
# Epoch  9, CIFAR-10 Batch 2:  cost: 1.65286
# Accuracy: 0.346
# Epoch  9, CIFAR-10 Batch 3:  cost: 1.41464
# Accuracy: 0.3426
# Epoch  9, CIFAR-10 Batch 4:  cost: 1.59348
# Accuracy: 0.3544
# Epoch  9, CIFAR-10 Batch 5:  cost: 1.31116
# Accuracy: 0.3542
# Epoch 10, CIFAR-10 Batch 1:  cost: 1.47674
# Accuracy: 0.3604
# Epoch 10, CIFAR-10 Batch 2:  cost: 1.57311
# Accuracy: 0.3702
# Epoch 10, CIFAR-10 Batch 3:  cost: 1.37997
# Accuracy: 0.3652
# Epoch 10, CIFAR-10 Batch 4:  cost: 1.51629
# Accuracy: 0.3704
# Epoch 10, CIFAR-10 Batch 5:  cost: 1.22864
# Accuracy: 0.372
# Epoch 11, CIFAR-10 Batch 1:  cost: 1.37838
# Accuracy: 0.3722
# Epoch 11, CIFAR-10 Batch 2:  cost: 1.52882
# Accuracy: 0.3802
# Epoch 11, CIFAR-10 Batch 3:  cost: 1.31045
# Accuracy: 0.3752
# Epoch 11, CIFAR-10 Batch 4:  cost: 1.39215
# Accuracy: 0.38
# Epoch 11, CIFAR-10 Batch 5:  cost: 1.15543
# Accuracy: 0.3864
# Epoch 12, CIFAR-10 Batch 1:  cost: 1.3275
# Accuracy: 0.3832
# Epoch 12, CIFAR-10 Batch 2:  cost: 1.46073
# Accuracy: 0.3848
# Epoch 12, CIFAR-10 Batch 3:  cost: 1.31481
# Accuracy: 0.3784
# Epoch 12, CIFAR-10 Batch 4:  cost: 1.35642
# Accuracy: 0.3838
# Epoch 12, CIFAR-10 Batch 5:  cost: 1.13133
# Accuracy: 0.393
# Epoch 13, CIFAR-10 Batch 1:  cost: 1.34615
# Accuracy: 0.3906
# Epoch 13, CIFAR-10 Batch 2:  cost: 1.45869
# Accuracy: 0.3978
# Epoch 13, CIFAR-10 Batch 3:  cost: 1.22013
# Accuracy: 0.3956
# Epoch 13, CIFAR-10 Batch 4:  cost: 1.33491
# Accuracy: 0.3924
# Epoch 13, CIFAR-10 Batch 5:  cost: 1.19107
# Accuracy: 0.3996
# Epoch 14, CIFAR-10 Batch 1:  cost: 1.33087
# Accuracy: 0.3938
# Epoch 14, CIFAR-10 Batch 2:  cost: 1.42557
# Accuracy: 0.4038
# Epoch 14, CIFAR-10 Batch 3:  cost: 1.20118
# Accuracy: 0.4014
# Epoch 14, CIFAR-10 Batch 4:  cost: 1.3422
# Accuracy: 0.3976
# Epoch 14, CIFAR-10 Batch 5:  cost: 1.11738
# Accuracy: 0.3926
# Epoch 15, CIFAR-10 Batch 1:  cost: 1.28275
# Accuracy: 0.407
# Epoch 15, CIFAR-10 Batch 2:  cost: 1.41834
# Accuracy: 0.4038
# Epoch 15, CIFAR-10 Batch 3:  cost: 1.15725
# Accuracy: 0.4066
# Epoch 15, CIFAR-10 Batch 4:  cost: 1.3276
# Accuracy: 0.404
# Epoch 15, CIFAR-10 Batch 5:  cost: 1.12008
# Accuracy: 0.3924
# Epoch 16, CIFAR-10 Batch 1:  cost: 1.19316
# Accuracy: 0.4198
# Epoch 16, CIFAR-10 Batch 2:  cost: 1.34225
# Accuracy: 0.4072
# Epoch 16, CIFAR-10 Batch 3:  cost: 1.14196
# Accuracy: 0.4162
# Epoch 16, CIFAR-10 Batch 4:  cost: 1.28227
# Accuracy: 0.4032
# Epoch 16, CIFAR-10 Batch 5:  cost: 1.14321
# Accuracy: 0.3976
# Epoch 17, CIFAR-10 Batch 1:  cost: 1.16929
# Accuracy: 0.4088
# Epoch 17, CIFAR-10 Batch 2:  cost: 1.34195
# Accuracy: 0.4142
# Epoch 17, CIFAR-10 Batch 3:  cost: 1.10676
# Accuracy: 0.4046
# Epoch 17, CIFAR-10 Batch 4:  cost: 1.29133
# Accuracy: 0.4048
# Epoch 17, CIFAR-10 Batch 5:  cost: 1.08103
# Accuracy: 0.4058
# Epoch 18, CIFAR-10 Batch 1:  cost: 1.06152
# Accuracy: 0.4128
# Epoch 18, CIFAR-10 Batch 2:  cost: 1.30271
# Accuracy: 0.4052
# Epoch 18, CIFAR-10 Batch 3:  cost: 1.0852
# Accuracy: 0.411
# Epoch 18, CIFAR-10 Batch 4:  cost: 1.24007
# Accuracy: 0.4176
# Epoch 18, CIFAR-10 Batch 5:  cost: 1.05063
# Accuracy: 0.4098
# Epoch 19, CIFAR-10 Batch 1:  cost: 1.05943
# Accuracy: 0.4172
# Epoch 19, CIFAR-10 Batch 2:  cost: 1.3039
# Accuracy: 0.42
# Epoch 19, CIFAR-10 Batch 3:  cost: 1.06975
# Accuracy: 0.413
# Epoch 19, CIFAR-10 Batch 4:  cost: 1.21707
# Accuracy: 0.4188
# Epoch 19, CIFAR-10 Batch 5:  cost: 1.02929
# Accuracy: 0.4134
# Epoch 20, CIFAR-10 Batch 1:  cost: 1.03117
# Accuracy: 0.4184
# Epoch 20, CIFAR-10 Batch 2:  cost: 1.31731
# Accuracy: 0.4184
# Epoch 20, CIFAR-10 Batch 3:  cost: 1.05451
# Accuracy: 0.4268
# Epoch 20, CIFAR-10 Batch 4:  cost: 1.16421
# Accuracy: 0.413
# Epoch 20, CIFAR-10 Batch 5:  cost: 1.03845
# Accuracy: 0.4126
# Epoch 21, CIFAR-10 Batch 1:  cost: 0.996958
# Accuracy: 0.431
# Epoch 21, CIFAR-10 Batch 2:  cost: 1.28575
# Accuracy: 0.4282
# Epoch 21, CIFAR-10 Batch 3:  cost: 1.01044
# Accuracy: 0.4326
# Epoch 21, CIFAR-10 Batch 4:  cost: 1.1447
# Accuracy: 0.4494
# Epoch 21, CIFAR-10 Batch 5:  cost: 0.960798
# Accuracy: 0.4502
# Epoch 22, CIFAR-10 Batch 1:  cost: 0.9476
# Accuracy: 0.4682
# Epoch 22, CIFAR-10 Batch 2:  cost: 1.13432
# Accuracy: 0.458
# Epoch 22, CIFAR-10 Batch 3:  cost: 0.908685
# Accuracy: 0.473
# Epoch 22, CIFAR-10 Batch 4:  cost: 1.10314
# Accuracy: 0.4682
# Epoch 22, CIFAR-10 Batch 5:  cost: 0.876397
# Accuracy: 0.4876
# Epoch 23, CIFAR-10 Batch 1:  cost: 0.83979
# Accuracy: 0.486
# Epoch 23, CIFAR-10 Batch 2:  cost: 1.01614
# Accuracy: 0.4812
# Epoch 23, CIFAR-10 Batch 3:  cost: 0.837377
# Accuracy: 0.4976
# Epoch 23, CIFAR-10 Batch 4:  cost: 1.04194
# Accuracy: 0.4978
# Epoch 23, CIFAR-10 Batch 5:  cost: 0.855111
# Accuracy: 0.5008
# Epoch 24, CIFAR-10 Batch 1:  cost: 0.809617
# Accuracy: 0.498
# Epoch 24, CIFAR-10 Batch 2:  cost: 0.960906
# Accuracy: 0.5184
# Epoch 24, CIFAR-10 Batch 3:  cost: 0.769545
# Accuracy: 0.5148
# Epoch 24, CIFAR-10 Batch 4:  cost: 1.0316
# Accuracy: 0.52
# Epoch 24, CIFAR-10 Batch 5:  cost: 0.788114
# Accuracy: 0.511
# Epoch 25, CIFAR-10 Batch 1:  cost: 0.728429
# Accuracy: 0.5334
# Epoch 25, CIFAR-10 Batch 2:  cost: 0.839217
# Accuracy: 0.5368
# Epoch 25, CIFAR-10 Batch 3:  cost: 0.721669
# Accuracy: 0.5464
# Epoch 25, CIFAR-10 Batch 4:  cost: 1.05922
# Accuracy: 0.5104
# Epoch 25, CIFAR-10 Batch 5:  cost: 0.712356
# Accuracy: 0.5314
# Epoch 26, CIFAR-10 Batch 1:  cost: 0.700146
# Accuracy: 0.5368
# Epoch 26, CIFAR-10 Batch 2:  cost: 0.803623
# Accuracy: 0.5326
# Epoch 26, CIFAR-10 Batch 3:  cost: 0.698476
# Accuracy: 0.5404
# Epoch 26, CIFAR-10 Batch 4:  cost: 0.979917
# Accuracy: 0.5502
# Epoch 26, CIFAR-10 Batch 5:  cost: 0.688827
# Accuracy: 0.5272
# Epoch 27, CIFAR-10 Batch 1:  cost: 0.683966
# Accuracy: 0.5504
# Epoch 27, CIFAR-10 Batch 2:  cost: 0.899451
# Accuracy: 0.5462
# Epoch 27, CIFAR-10 Batch 3:  cost: 0.69911
# Accuracy: 0.5472
# Epoch 27, CIFAR-10 Batch 4:  cost: 0.945929
# Accuracy: 0.5568
# Epoch 27, CIFAR-10 Batch 5:  cost: 0.665743
# Accuracy: 0.5466
# Epoch 28, CIFAR-10 Batch 1:  cost: 0.66097
# Accuracy: 0.559
# Epoch 28, CIFAR-10 Batch 2:  cost: 0.771053
# Accuracy: 0.557
# Epoch 28, CIFAR-10 Batch 3:  cost: 0.6459
# Accuracy: 0.5606
# Epoch 28, CIFAR-10 Batch 4:  cost: 1.03022
# Accuracy: 0.5642
# Epoch 28, CIFAR-10 Batch 5:  cost: 0.616646
# Accuracy: 0.5464
# Epoch 29, CIFAR-10 Batch 1:  cost: 0.647273
# Accuracy: 0.5626
# Epoch 29, CIFAR-10 Batch 2:  cost: 0.820383
# Accuracy: 0.5748
# Epoch 29, CIFAR-10 Batch 3:  cost: 0.61317
# Accuracy: 0.5696
# Epoch 29, CIFAR-10 Batch 4:  cost: 0.896585
# Accuracy: 0.565
# Epoch 29, CIFAR-10 Batch 5:  cost: 0.603143
# Accuracy: 0.556
# Epoch 30, CIFAR-10 Batch 1:  cost: 0.626549
# Accuracy: 0.5648
# Epoch 30, CIFAR-10 Batch 2:  cost: 0.758858
# Accuracy: 0.5728
# Epoch 30, CIFAR-10 Batch 3:  cost: 0.600328
# Accuracy: 0.5684
# Epoch 30, CIFAR-10 Batch 4:  cost: 0.804168
# Accuracy: 0.5692
# Epoch 30, CIFAR-10 Batch 5:  cost: 0.566141
# Accuracy: 0.569
# Epoch 31, CIFAR-10 Batch 1:  cost: 0.601854
# Accuracy: 0.577
# Epoch 31, CIFAR-10 Batch 2:  cost: 0.661594
# Accuracy: 0.5768
# Epoch 31, CIFAR-10 Batch 3:  cost: 0.543303
# Accuracy: 0.5786
# Epoch 31, CIFAR-10 Batch 4:  cost: 0.82937
# Accuracy: 0.5798
# Epoch 31, CIFAR-10 Batch 5:  cost: 0.5605
# Accuracy: 0.5838
# Epoch 32, CIFAR-10 Batch 1:  cost: 0.593134
# Accuracy: 0.5944
# Epoch 32, CIFAR-10 Batch 2:  cost: 0.649902
# Accuracy: 0.5802
# Epoch 32, CIFAR-10 Batch 3:  cost: 0.515832
# Accuracy: 0.581
# Epoch 32, CIFAR-10 Batch 4:  cost: 0.794717
# Accuracy: 0.5904
# Epoch 32, CIFAR-10 Batch 5:  cost: 0.514401
# Accuracy: 0.5948
# Epoch 33, CIFAR-10 Batch 1:  cost: 0.557104
# Accuracy: 0.6004
# Epoch 33, CIFAR-10 Batch 2:  cost: 0.633057
# Accuracy: 0.5734
# Epoch 33, CIFAR-10 Batch 3:  cost: 0.460146
# Accuracy: 0.5954
# Epoch 33, CIFAR-10 Batch 4:  cost: 0.701811
# Accuracy: 0.594
# Epoch 33, CIFAR-10 Batch 5:  cost: 0.485409
# Accuracy: 0.6046
# Epoch 34, CIFAR-10 Batch 1:  cost: 0.531267
# Accuracy: 0.5936
# Epoch 34, CIFAR-10 Batch 2:  cost: 0.643315
# Accuracy: 0.5886
# Epoch 34, CIFAR-10 Batch 3:  cost: 0.399851
# Accuracy: 0.5974
# Epoch 34, CIFAR-10 Batch 4:  cost: 0.62958
# Accuracy: 0.5974
# Epoch 34, CIFAR-10 Batch 5:  cost: 0.47462
# Accuracy: 0.6074
# Epoch 35, CIFAR-10 Batch 1:  cost: 0.585523
# Accuracy: 0.6022
# Epoch 35, CIFAR-10 Batch 2:  cost: 0.673729
# Accuracy: 0.5892
# Epoch 35, CIFAR-10 Batch 3:  cost: 0.443049
# Accuracy: 0.5968
# Epoch 35, CIFAR-10 Batch 4:  cost: 0.625355
# Accuracy: 0.5968
# Epoch 35, CIFAR-10 Batch 5:  cost: 0.399756
# Accuracy: 0.6132
# Epoch 36, CIFAR-10 Batch 1:  cost: 0.552117
# Accuracy: 0.6112
# Epoch 36, CIFAR-10 Batch 2:  cost: 0.631528
# Accuracy: 0.6006
# Epoch 36, CIFAR-10 Batch 3:  cost: 0.368002
# Accuracy: 0.601
# Epoch 36, CIFAR-10 Batch 4:  cost: 0.604365
# Accuracy: 0.6016
# Epoch 36, CIFAR-10 Batch 5:  cost: 0.397727
# Accuracy: 0.6094
# Epoch 37, CIFAR-10 Batch 1:  cost: 0.51059
# Accuracy: 0.6078
# Epoch 37, CIFAR-10 Batch 2:  cost: 0.588364
# Accuracy: 0.609
# Epoch 37, CIFAR-10 Batch 3:  cost: 0.370286
# Accuracy: 0.6064
# Epoch 37, CIFAR-10 Batch 4:  cost: 0.47639
# Accuracy: 0.606
# Epoch 37, CIFAR-10 Batch 5:  cost: 0.391433
# Accuracy: 0.6202
# Epoch 38, CIFAR-10 Batch 1:  cost: 0.534667
# Accuracy: 0.6062
# Epoch 38, CIFAR-10 Batch 2:  cost: 0.502339
# Accuracy: 0.6096
# Epoch 38, CIFAR-10 Batch 3:  cost: 0.33571
# Accuracy: 0.6172
# Epoch 38, CIFAR-10 Batch 4:  cost: 0.480008
# Accuracy: 0.6122
# Epoch 38, CIFAR-10 Batch 5:  cost: 0.374331
# Accuracy: 0.6166
# Epoch 39, CIFAR-10 Batch 1:  cost: 0.516176
# Accuracy: 0.6034
# Epoch 39, CIFAR-10 Batch 2:  cost: 0.454393
# Accuracy: 0.6084
# Epoch 39, CIFAR-10 Batch 3:  cost: 0.313205
# Accuracy: 0.6158
# Epoch 39, CIFAR-10 Batch 4:  cost: 0.51088
# Accuracy: 0.6086
# Epoch 39, CIFAR-10 Batch 5:  cost: 0.379459
# Accuracy: 0.621
# Epoch 40, CIFAR-10 Batch 1:  cost: 0.530354
# Accuracy: 0.615
# Epoch 40, CIFAR-10 Batch 2:  cost: 0.474656
# Accuracy: 0.6094
# Epoch 40, CIFAR-10 Batch 3:  cost: 0.273606
# Accuracy: 0.614
# Epoch 40, CIFAR-10 Batch 4:  cost: 0.486953
# Accuracy: 0.6178
# Epoch 40, CIFAR-10 Batch 5:  cost: 0.370293
# Accuracy: 0.6254
# Epoch 41, CIFAR-10 Batch 1:  cost: 0.468045
# Accuracy: 0.6034
# Epoch 41, CIFAR-10 Batch 2:  cost: 0.404773
# Accuracy: 0.6084
# Epoch 41, CIFAR-10 Batch 3:  cost: 0.350919
# Accuracy: 0.6182
# Epoch 41, CIFAR-10 Batch 4:  cost: 0.464834
# Accuracy: 0.6194
# Epoch 41, CIFAR-10 Batch 5:  cost: 0.346995
# Accuracy: 0.6264
# Epoch 42, CIFAR-10 Batch 1:  cost: 0.459954
# Accuracy: 0.6112
# Epoch 42, CIFAR-10 Batch 2:  cost: 0.459936
# Accuracy: 0.613
# Epoch 42, CIFAR-10 Batch 3:  cost: 0.273388
# Accuracy: 0.617
# Epoch 42, CIFAR-10 Batch 4:  cost: 0.426955
# Accuracy: 0.6112
# Epoch 42, CIFAR-10 Batch 5:  cost: 0.33614
# Accuracy: 0.6266
# Epoch 43, CIFAR-10 Batch 1:  cost: 0.483871
# Accuracy: 0.6164
# Epoch 43, CIFAR-10 Batch 2:  cost: 0.314512
# Accuracy: 0.6124
# Epoch 43, CIFAR-10 Batch 3:  cost: 0.213928
# Accuracy: 0.6142
# Epoch 43, CIFAR-10 Batch 4:  cost: 0.443398
# Accuracy: 0.6066
# Epoch 43, CIFAR-10 Batch 5:  cost: 0.359092
# Accuracy: 0.6144
# Epoch 44, CIFAR-10 Batch 1:  cost: 0.347249
# Accuracy: 0.6168
# Epoch 44, CIFAR-10 Batch 2:  cost: 0.35001
# Accuracy: 0.6196
# Epoch 44, CIFAR-10 Batch 3:  cost: 0.236248
# Accuracy: 0.6208
# Epoch 44, CIFAR-10 Batch 4:  cost: 0.362919
# Accuracy: 0.6062
# Epoch 44, CIFAR-10 Batch 5:  cost: 0.366451
# Accuracy: 0.6094
# Epoch 45, CIFAR-10 Batch 1:  cost: 0.379711
# Accuracy: 0.618
# Epoch 45, CIFAR-10 Batch 2:  cost: 0.283051
# Accuracy: 0.619
# Epoch 45, CIFAR-10 Batch 3:  cost: 0.222546
# Accuracy: 0.625
# Epoch 45, CIFAR-10 Batch 4:  cost: 0.381095
# Accuracy: 0.6178
# Epoch 45, CIFAR-10 Batch 5:  cost: 0.369621
# Accuracy: 0.6192
# Epoch 46, CIFAR-10 Batch 1:  cost: 0.470547
# Accuracy: 0.6206
# Epoch 46, CIFAR-10 Batch 2:  cost: 0.303233
# Accuracy: 0.6184
# Epoch 46, CIFAR-10 Batch 3:  cost: 0.190754
# Accuracy: 0.6226
# Epoch 46, CIFAR-10 Batch 4:  cost: 0.341435
# Accuracy: 0.6094
# Epoch 46, CIFAR-10 Batch 5:  cost: 0.353703
# Accuracy: 0.6286
# Epoch 47, CIFAR-10 Batch 1:  cost: 0.324681
# Accuracy: 0.6254
# Epoch 47, CIFAR-10 Batch 2:  cost: 0.255674
# Accuracy: 0.6084
# Epoch 47, CIFAR-10 Batch 3:  cost: 0.207325
# Accuracy: 0.619
# Epoch 47, CIFAR-10 Batch 4:  cost: 0.328658
# Accuracy: 0.6042
# Epoch 47, CIFAR-10 Batch 5:  cost: 0.361306
# Accuracy: 0.63
# Epoch 48, CIFAR-10 Batch 1:  cost: 0.320584
# Accuracy: 0.617
# Epoch 48, CIFAR-10 Batch 2:  cost: 0.230503
# Accuracy: 0.6194
# Epoch 48, CIFAR-10 Batch 3:  cost: 0.18247
# Accuracy: 0.6226
# Epoch 48, CIFAR-10 Batch 4:  cost: 0.278494
# Accuracy: 0.612
# Epoch 48, CIFAR-10 Batch 5:  cost: 0.330352
# Accuracy: 0.6274
# Epoch 49, CIFAR-10 Batch 1:  cost: 0.282935
# Accuracy: 0.6198
# Epoch 49, CIFAR-10 Batch 2:  cost: 0.199217
# Accuracy: 0.6206
# Epoch 49, CIFAR-10 Batch 3:  cost: 0.152996
# Accuracy: 0.6308
# Epoch 49, CIFAR-10 Batch 4:  cost: 0.29887
# Accuracy: 0.6186
# Epoch 49, CIFAR-10 Batch 5:  cost: 0.323623
# Accuracy: 0.624
# Epoch 50, CIFAR-10 Batch 1:  cost: 0.249974
# Accuracy: 0.623
# Epoch 50, CIFAR-10 Batch 2:  cost: 0.23564
# Accuracy: 0.62
# Epoch 50, CIFAR-10 Batch 3:  cost: 0.131322
# Accuracy: 0.6244
# Epoch 50, CIFAR-10 Batch 4:  cost: 0.278618
# Accuracy: 0.6184
# Epoch 50, CIFAR-10 Batch 5:  cost: 0.359116
# Accuracy: 0.618
# Epoch 51, CIFAR-10 Batch 1:  cost: 0.279067
# Accuracy: 0.6236
# Epoch 51, CIFAR-10 Batch 2:  cost: 0.202713
# Accuracy: 0.6036
# Epoch 51, CIFAR-10 Batch 3:  cost: 0.175442
# Accuracy: 0.6212
# Epoch 51, CIFAR-10 Batch 4:  cost: 0.312958
# Accuracy: 0.6182
# Epoch 51, CIFAR-10 Batch 5:  cost: 0.277921
# Accuracy: 0.6258
# Epoch 52, CIFAR-10 Batch 1:  cost: 0.290293
# Accuracy: 0.6208
# Epoch 52, CIFAR-10 Batch 2:  cost: 0.166021
# Accuracy: 0.6154
# Epoch 52, CIFAR-10 Batch 3:  cost: 0.126579
# Accuracy: 0.6264
# Epoch 52, CIFAR-10 Batch 4:  cost: 0.253064
# Accuracy: 0.6174
# Epoch 52, CIFAR-10 Batch 5:  cost: 0.266949
# Accuracy: 0.625
# Epoch 53, CIFAR-10 Batch 1:  cost: 0.318118
# Accuracy: 0.6182
# Epoch 53, CIFAR-10 Batch 2:  cost: 0.168329
# Accuracy: 0.6184
# Epoch 53, CIFAR-10 Batch 3:  cost: 0.125426
# Accuracy: 0.6266
# Epoch 53, CIFAR-10 Batch 4:  cost: 0.279099
# Accuracy: 0.6214
# Epoch 53, CIFAR-10 Batch 5:  cost: 0.271065
# Accuracy: 0.6212
# Epoch 54, CIFAR-10 Batch 1:  cost: 0.268943
# Accuracy: 0.6294
# Epoch 54, CIFAR-10 Batch 2:  cost: 0.170308
# Accuracy: 0.6192
# Epoch 54, CIFAR-10 Batch 3:  cost: 0.128359
# Accuracy: 0.6126
# Epoch 54, CIFAR-10 Batch 4:  cost: 0.22653
# Accuracy: 0.6256
# Epoch 54, CIFAR-10 Batch 5:  cost: 0.308755
# Accuracy: 0.6274
# Epoch 55, CIFAR-10 Batch 1:  cost: 0.230726
# Accuracy: 0.626
# Epoch 55, CIFAR-10 Batch 2:  cost: 0.161748
# Accuracy: 0.6016
# Epoch 55, CIFAR-10 Batch 3:  cost: 0.118569
# Accuracy: 0.6164
# Epoch 55, CIFAR-10 Batch 4:  cost: 0.198077
# Accuracy: 0.6226
# Epoch 55, CIFAR-10 Batch 5:  cost: 0.24788
# Accuracy: 0.6178
# Epoch 56, CIFAR-10 Batch 1:  cost: 0.261428
# Accuracy: 0.6278
# Epoch 56, CIFAR-10 Batch 2:  cost: 0.16773
# Accuracy: 0.614
# Epoch 56, CIFAR-10 Batch 3:  cost: 0.0824014
# Accuracy: 0.6186
# Epoch 56, CIFAR-10 Batch 4:  cost: 0.257329
# Accuracy: 0.62
# Epoch 56, CIFAR-10 Batch 5:  cost: 0.252813
# Accuracy: 0.6166
# Epoch 57, CIFAR-10 Batch 1:  cost: 0.284538
# Accuracy: 0.6274
# Epoch 57, CIFAR-10 Batch 2:  cost: 0.179387
# Accuracy: 0.6192
# Epoch 57, CIFAR-10 Batch 3:  cost: 0.0724694
# Accuracy: 0.6222
# Epoch 57, CIFAR-10 Batch 4:  cost: 0.1844
# Accuracy: 0.6246
# Epoch 57, CIFAR-10 Batch 5:  cost: 0.245028
# Accuracy: 0.6254
# Epoch 58, CIFAR-10 Batch 1:  cost: 0.190782
# Accuracy: 0.6308
# Epoch 58, CIFAR-10 Batch 2:  cost: 0.128125
# Accuracy: 0.6238
# Epoch 58, CIFAR-10 Batch 3:  cost: 0.0782075
# Accuracy: 0.622
# Epoch 58, CIFAR-10 Batch 4:  cost: 0.192628
# Accuracy: 0.6128
# Epoch 58, CIFAR-10 Batch 5:  cost: 0.238973
# Accuracy: 0.6226
# Epoch 59, CIFAR-10 Batch 1:  cost: 0.150974
# Accuracy: 0.6302
# Epoch 59, CIFAR-10 Batch 2:  cost: 0.120089
# Accuracy: 0.624
# Epoch 59, CIFAR-10 Batch 3:  cost: 0.0856761
# Accuracy: 0.6278
# Epoch 59, CIFAR-10 Batch 4:  cost: 0.24779
# Accuracy: 0.6124
# Epoch 59, CIFAR-10 Batch 5:  cost: 0.224688
# Accuracy: 0.6264
# Epoch 60, CIFAR-10 Batch 1:  cost: 0.14559
# Accuracy: 0.6336
# Epoch 60, CIFAR-10 Batch 2:  cost: 0.100802
# Accuracy: 0.6186
# Epoch 60, CIFAR-10 Batch 3:  cost: 0.0542832
# Accuracy: 0.6262
# Epoch 60, CIFAR-10 Batch 4:  cost: 0.196848
# Accuracy: 0.6132
# Epoch 60, CIFAR-10 Batch 5:  cost: 0.206659
# Accuracy: 0.6248
# Epoch 61, CIFAR-10 Batch 1:  cost: 0.180075
# Accuracy: 0.6326
# Epoch 61, CIFAR-10 Batch 2:  cost: 0.156818
# Accuracy: 0.6254
# Epoch 61, CIFAR-10 Batch 3:  cost: 0.0678497
# Accuracy: 0.6228
# Epoch 61, CIFAR-10 Batch 4:  cost: 0.22691
# Accuracy: 0.6092
# Epoch 61, CIFAR-10 Batch 5:  cost: 0.202491
# Accuracy: 0.6196
# Epoch 62, CIFAR-10 Batch 1:  cost: 0.206137
# Accuracy: 0.627
# Epoch 62, CIFAR-10 Batch 2:  cost: 0.144527
# Accuracy: 0.6272
# Epoch 62, CIFAR-10 Batch 3:  cost: 0.105876
# Accuracy: 0.6244
# Epoch 62, CIFAR-10 Batch 4:  cost: 0.196861
# Accuracy: 0.6032
# Epoch 62, CIFAR-10 Batch 5:  cost: 0.200147
# Accuracy: 0.6222
# Epoch 63, CIFAR-10 Batch 1:  cost: 0.204296
# Accuracy: 0.6236
# Epoch 63, CIFAR-10 Batch 2:  cost: 0.112753
# Accuracy: 0.622
# Epoch 63, CIFAR-10 Batch 3:  cost: 0.0994457
# Accuracy: 0.6214
# Epoch 63, CIFAR-10 Batch 4:  cost: 0.191576
# Accuracy: 0.596
# Epoch 63, CIFAR-10 Batch 5:  cost: 0.181253
# Accuracy: 0.624
# Epoch 64, CIFAR-10 Batch 1:  cost: 0.187641
# Accuracy: 0.6252
# Epoch 64, CIFAR-10 Batch 2:  cost: 0.10087
# Accuracy: 0.629
# Epoch 64, CIFAR-10 Batch 3:  cost: 0.0499996
# Accuracy: 0.6282
# Epoch 64, CIFAR-10 Batch 4:  cost: 0.166346
# Accuracy: 0.6184
# Epoch 64, CIFAR-10 Batch 5:  cost: 0.246449
# Accuracy: 0.6256
# Epoch 65, CIFAR-10 Batch 1:  cost: 0.167496
# Accuracy: 0.6352
# Epoch 65, CIFAR-10 Batch 2:  cost: 0.120738
# Accuracy: 0.6186
# Epoch 65, CIFAR-10 Batch 3:  cost: 0.0469847
# Accuracy: 0.6268
# Epoch 65, CIFAR-10 Batch 4:  cost: 0.179055
# Accuracy: 0.6126
# Epoch 65, CIFAR-10 Batch 5:  cost: 0.163508
# Accuracy: 0.6244
# Epoch 66, CIFAR-10 Batch 1:  cost: 0.157468
# Accuracy: 0.619
# Epoch 66, CIFAR-10 Batch 2:  cost: 0.0932752
# Accuracy: 0.621
# Epoch 66, CIFAR-10 Batch 3:  cost: 0.0423678
# Accuracy: 0.6244
# Epoch 66, CIFAR-10 Batch 4:  cost: 0.142562
# Accuracy: 0.621
# Epoch 66, CIFAR-10 Batch 5:  cost: 0.115231
# Accuracy: 0.6312
# Epoch 67, CIFAR-10 Batch 1:  cost: 0.173712
# Accuracy: 0.6252
# Epoch 67, CIFAR-10 Batch 2:  cost: 0.0896356
# Accuracy: 0.6228
# Epoch 67, CIFAR-10 Batch 3:  cost: 0.115787
# Accuracy: 0.622
# Epoch 67, CIFAR-10 Batch 4:  cost: 0.145494
# Accuracy: 0.6122
# Epoch 67, CIFAR-10 Batch 5:  cost: 0.109885
# Accuracy: 0.6192
# Epoch 68, CIFAR-10 Batch 1:  cost: 0.237048
# Accuracy: 0.6256
# Epoch 68, CIFAR-10 Batch 2:  cost: 0.0911966
# Accuracy: 0.6274
# Epoch 68, CIFAR-10 Batch 3:  cost: 0.150883
# Accuracy: 0.622
# Epoch 68, CIFAR-10 Batch 4:  cost: 0.152467
# Accuracy: 0.622
# Epoch 68, CIFAR-10 Batch 5:  cost: 0.0870334
# Accuracy: 0.6288
# Epoch 69, CIFAR-10 Batch 1:  cost: 0.113672
# Accuracy: 0.6372
# Epoch 69, CIFAR-10 Batch 2:  cost: 0.0842753
# Accuracy: 0.634
# Epoch 69, CIFAR-10 Batch 3:  cost: 0.117871
# Accuracy: 0.616
# Epoch 69, CIFAR-10 Batch 4:  cost: 0.145388
# Accuracy: 0.6224
# Epoch 69, CIFAR-10 Batch 5:  cost: 0.105143
# Accuracy: 0.625
# Epoch 70, CIFAR-10 Batch 1:  cost: 0.147791
# Accuracy: 0.6338
# Epoch 70, CIFAR-10 Batch 2:  cost: 0.100163
# Accuracy: 0.6338
# Epoch 70, CIFAR-10 Batch 3:  cost: 0.115925
# Accuracy: 0.6346
# Epoch 70, CIFAR-10 Batch 4:  cost: 0.155328
# Accuracy: 0.622
# Epoch 70, CIFAR-10 Batch 5:  cost: 0.0626989
# Accuracy: 0.6254
# Epoch 71, CIFAR-10 Batch 1:  cost: 0.159849
# Accuracy: 0.6286
# Epoch 71, CIFAR-10 Batch 2:  cost: 0.086432
# Accuracy: 0.6294
# Epoch 71, CIFAR-10 Batch 3:  cost: 0.144779
# Accuracy: 0.625
# Epoch 71, CIFAR-10 Batch 4:  cost: 0.167029
# Accuracy: 0.6136
# Epoch 71, CIFAR-10 Batch 5:  cost: 0.115508
# Accuracy: 0.6248
# Epoch 72, CIFAR-10 Batch 1:  cost: 0.173343
# Accuracy: 0.6212
# Epoch 72, CIFAR-10 Batch 2:  cost: 0.0865951
# Accuracy: 0.6278
# Epoch 72, CIFAR-10 Batch 3:  cost: 0.0471814
# Accuracy: 0.621
# Epoch 72, CIFAR-10 Batch 4:  cost: 0.136854
# Accuracy: 0.6114
# Epoch 72, CIFAR-10 Batch 5:  cost: 0.0985857
# Accuracy: 0.6212
# Epoch 73, CIFAR-10 Batch 1:  cost: 0.140157
# Accuracy: 0.626
# Epoch 73, CIFAR-10 Batch 2:  cost: 0.0800275
# Accuracy: 0.6252
# Epoch 73, CIFAR-10 Batch 3:  cost: 0.0412467
# Accuracy: 0.6258
# Epoch 73, CIFAR-10 Batch 4:  cost: 0.13916
# Accuracy: 0.6216
# Epoch 73, CIFAR-10 Batch 5:  cost: 0.0820494
# Accuracy: 0.6294
# Epoch 74, CIFAR-10 Batch 1:  cost: 0.18935
# Accuracy: 0.634
# Epoch 74, CIFAR-10 Batch 2:  cost: 0.0512552
# Accuracy: 0.6298
# Epoch 74, CIFAR-10 Batch 3:  cost: 0.0420564
# Accuracy: 0.624
# Epoch 74, CIFAR-10 Batch 4:  cost: 0.137698
# Accuracy: 0.6194
# Epoch 74, CIFAR-10 Batch 5:  cost: 0.0505279
# Accuracy: 0.6234
# Epoch 75, CIFAR-10 Batch 1:  cost: 0.180647
# Accuracy: 0.6262
# Epoch 75, CIFAR-10 Batch 2:  cost: 0.0596893
# Accuracy: 0.6242
# Epoch 75, CIFAR-10 Batch 3:  cost: 0.0344644
# Accuracy: 0.625
# Epoch 75, CIFAR-10 Batch 4:  cost: 0.143321
# Accuracy: 0.6284
# Epoch 75, CIFAR-10 Batch 5:  cost: 0.0365492
# Accuracy: 0.6292
# Epoch 76, CIFAR-10 Batch 1:  cost: 0.162811
# Accuracy: 0.6258
# Epoch 76, CIFAR-10 Batch 2:  cost: 0.074693
# Accuracy: 0.6296
# Epoch 76, CIFAR-10 Batch 3:  cost: 0.0243361
# Accuracy: 0.6266
# Epoch 76, CIFAR-10 Batch 4:  cost: 0.146194
# Accuracy: 0.6238
# Epoch 76, CIFAR-10 Batch 5:  cost: 0.0388282
# Accuracy: 0.6238
# Epoch 77, CIFAR-10 Batch 1:  cost: 0.192412
# Accuracy: 0.6322
# Epoch 77, CIFAR-10 Batch 2:  cost: 0.0779364
# Accuracy: 0.623
# Epoch 77, CIFAR-10 Batch 3:  cost: 0.0345229
# Accuracy: 0.6232
# Epoch 77, CIFAR-10 Batch 4:  cost: 0.141964
# Accuracy: 0.6196
# Epoch 77, CIFAR-10 Batch 5:  cost: 0.0383167
# Accuracy: 0.6288
# Epoch 78, CIFAR-10 Batch 1:  cost: 0.121732
# Accuracy: 0.6282
# Epoch 78, CIFAR-10 Batch 2:  cost: 0.0826211
# Accuracy: 0.6266
# Epoch 78, CIFAR-10 Batch 3:  cost: 0.0247363
# Accuracy: 0.623
# Epoch 78, CIFAR-10 Batch 4:  cost: 0.139959
# Accuracy: 0.6284
# Epoch 78, CIFAR-10 Batch 5:  cost: 0.0749244
# Accuracy: 0.6304
# Epoch 79, CIFAR-10 Batch 1:  cost: 0.131928
# Accuracy: 0.6236
# Epoch 79, CIFAR-10 Batch 2:  cost: 0.0828396
# Accuracy: 0.6254
# Epoch 79, CIFAR-10 Batch 3:  cost: 0.0661564
# Accuracy: 0.6202
# Epoch 79, CIFAR-10 Batch 4:  cost: 0.133986
# Accuracy: 0.6248
# Epoch 79, CIFAR-10 Batch 5:  cost: 0.0424531
# Accuracy: 0.634
# Epoch 80, CIFAR-10 Batch 1:  cost: 0.115855
# Accuracy: 0.639
# Epoch 80, CIFAR-10 Batch 2:  cost: 0.0829175
# Accuracy: 0.6358
# Epoch 80, CIFAR-10 Batch 3:  cost: 0.0306644
# Accuracy: 0.6272
# Epoch 80, CIFAR-10 Batch 4:  cost: 0.147357
# Accuracy: 0.624
# Epoch 80, CIFAR-10 Batch 5:  cost: 0.0477612
# Accuracy: 0.6262
# Epoch 81, CIFAR-10 Batch 1:  cost: 0.113673
# Accuracy: 0.631
# Epoch 81, CIFAR-10 Batch 2:  cost: 0.0685945
# Accuracy: 0.6296
# Epoch 81, CIFAR-10 Batch 3:  cost: 0.0213917
# Accuracy: 0.628
# Epoch 81, CIFAR-10 Batch 4:  cost: 0.129186
# Accuracy: 0.624
# Epoch 81, CIFAR-10 Batch 5:  cost: 0.0275058
# Accuracy: 0.625
# Epoch 82, CIFAR-10 Batch 1:  cost: 0.155145
# Accuracy: 0.6246
# Epoch 82, CIFAR-10 Batch 2:  cost: 0.0818388
# Accuracy: 0.6174
# Epoch 82, CIFAR-10 Batch 3:  cost: 0.0316144
# Accuracy: 0.6238
# Epoch 82, CIFAR-10 Batch 4:  cost: 0.142844
# Accuracy: 0.6252
# Epoch 82, CIFAR-10 Batch 5:  cost: 0.0354208
# Accuracy: 0.6326
# Epoch 83, CIFAR-10 Batch 1:  cost: 0.117479
# Accuracy: 0.6338
# Epoch 83, CIFAR-10 Batch 2:  cost: 0.110543
# Accuracy: 0.6264
# Epoch 83, CIFAR-10 Batch 3:  cost: 0.032867
# Accuracy: 0.6286
# Epoch 83, CIFAR-10 Batch 4:  cost: 0.148899
# Accuracy: 0.6302
# Epoch 83, CIFAR-10 Batch 5:  cost: 0.0231984
# Accuracy: 0.6268
# Epoch 84, CIFAR-10 Batch 1:  cost: 0.157698
# Accuracy: 0.6372
# Epoch 84, CIFAR-10 Batch 2:  cost: 0.0728485
# Accuracy: 0.6326
# Epoch 84, CIFAR-10 Batch 3:  cost: 0.0243669
# Accuracy: 0.6272
# Epoch 84, CIFAR-10 Batch 4:  cost: 0.131402
# Accuracy: 0.6352
# Epoch 84, CIFAR-10 Batch 5:  cost: 0.0270793
# Accuracy: 0.628
# Epoch 85, CIFAR-10 Batch 1:  cost: 0.0926077
# Accuracy: 0.6308
# Epoch 85, CIFAR-10 Batch 2:  cost: 0.103181
# Accuracy: 0.6248
# Epoch 85, CIFAR-10 Batch 3:  cost: 0.0195728
# Accuracy: 0.6282
# Epoch 85, CIFAR-10 Batch 4:  cost: 0.146037
# Accuracy: 0.6248
# Epoch 85, CIFAR-10 Batch 5:  cost: 0.0259933
# Accuracy: 0.6304
# Epoch 86, CIFAR-10 Batch 1:  cost: 0.117126
# Accuracy: 0.6288
# Epoch 86, CIFAR-10 Batch 2:  cost: 0.0690862
# Accuracy: 0.6298
# Epoch 86, CIFAR-10 Batch 3:  cost: 0.0236298
# Accuracy: 0.6216
# Epoch 86, CIFAR-10 Batch 4:  cost: 0.130215
# Accuracy: 0.628
# Epoch 86, CIFAR-10 Batch 5:  cost: 0.0217795
# Accuracy: 0.6276
# Epoch 87, CIFAR-10 Batch 1:  cost: 0.0795015
# Accuracy: 0.6308
# Epoch 87, CIFAR-10 Batch 2:  cost: 0.0867403
# Accuracy: 0.6356
# Epoch 87, CIFAR-10 Batch 3:  cost: 0.0411367
# Accuracy: 0.6282
# Epoch 87, CIFAR-10 Batch 4:  cost: 0.139734
# Accuracy: 0.6304
# Epoch 87, CIFAR-10 Batch 5:  cost: 0.0324365
# Accuracy: 0.6282
# Epoch 88, CIFAR-10 Batch 1:  cost: 0.199404
# Accuracy: 0.6296
# Epoch 88, CIFAR-10 Batch 2:  cost: 0.0698691
# Accuracy: 0.6252
# Epoch 88, CIFAR-10 Batch 3:  cost: 0.0206878
# Accuracy: 0.6294
# Epoch 88, CIFAR-10 Batch 4:  cost: 0.129579
# Accuracy: 0.6212
# Epoch 88, CIFAR-10 Batch 5:  cost: 0.0233535
# Accuracy: 0.6192
# Epoch 89, CIFAR-10 Batch 1:  cost: 0.134609
# Accuracy: 0.6272
# Epoch 89, CIFAR-10 Batch 2:  cost: 0.0584292
# Accuracy: 0.6282
# Epoch 89, CIFAR-10 Batch 3:  cost: 0.0257138
# Accuracy: 0.6254
# Epoch 89, CIFAR-10 Batch 4:  cost: 0.132787
# Accuracy: 0.625
# Epoch 89, CIFAR-10 Batch 5:  cost: 0.0301738
# Accuracy: 0.6232
# Epoch 90, CIFAR-10 Batch 1:  cost: 0.0940639
# Accuracy: 0.6362
# Epoch 90, CIFAR-10 Batch 2:  cost: 0.0641385
# Accuracy: 0.6254
# Epoch 90, CIFAR-10 Batch 3:  cost: 0.0152377
# Accuracy: 0.6296
# Epoch 90, CIFAR-10 Batch 4:  cost: 0.126404
# Accuracy: 0.633
# Epoch 90, CIFAR-10 Batch 5:  cost: 0.0287079
# Accuracy: 0.6296
# Epoch 91, CIFAR-10 Batch 1:  cost: 0.131653
# Accuracy: 0.6316
# Epoch 91, CIFAR-10 Batch 2:  cost: 0.0744615
# Accuracy: 0.6226
# Epoch 91, CIFAR-10 Batch 3:  cost: 0.0212127
# Accuracy: 0.6328
# Epoch 91, CIFAR-10 Batch 4:  cost: 0.137686
# Accuracy: 0.6262
# Epoch 91, CIFAR-10 Batch 5:  cost: 0.0256959
# Accuracy: 0.6286
# Epoch 92, CIFAR-10 Batch 1:  cost: 0.444226
# Accuracy: 0.6242
# Epoch 92, CIFAR-10 Batch 2:  cost: 0.0623971
# Accuracy: 0.6304
# Epoch 92, CIFAR-10 Batch 3:  cost: 0.0248974
# Accuracy: 0.6266
# Epoch 92, CIFAR-10 Batch 4:  cost: 0.132215
# Accuracy: 0.622
# Epoch 92, CIFAR-10 Batch 5:  cost: 0.0262309
# Accuracy: 0.633
# Epoch 93, CIFAR-10 Batch 1:  cost: 0.112602
# Accuracy: 0.6238
# Epoch 93, CIFAR-10 Batch 2:  cost: 0.0650281
# Accuracy: 0.6274
# Epoch 93, CIFAR-10 Batch 3:  cost: 0.0165358
# Accuracy: 0.6182
# Epoch 93, CIFAR-10 Batch 4:  cost: 0.143173
# Accuracy: 0.6156
# Epoch 93, CIFAR-10 Batch 5:  cost: 0.0246903
# Accuracy: 0.6348
# Epoch 94, CIFAR-10 Batch 1:  cost: 0.112282
# Accuracy: 0.6322
# Epoch 94, CIFAR-10 Batch 2:  cost: 0.0533097
# Accuracy: 0.6256
# Epoch 94, CIFAR-10 Batch 3:  cost: 0.0228128
# Accuracy: 0.627
# Epoch 94, CIFAR-10 Batch 4:  cost: 0.139185
# Accuracy: 0.629
# Epoch 94, CIFAR-10 Batch 5:  cost: 0.0221759
# Accuracy: 0.6218
# Epoch 95, CIFAR-10 Batch 1:  cost: 0.0946402
# Accuracy: 0.6306
# Epoch 95, CIFAR-10 Batch 2:  cost: 0.0393731
# Accuracy: 0.6298
# Epoch 95, CIFAR-10 Batch 3:  cost: 0.0173784
# Accuracy: 0.629
# Epoch 95, CIFAR-10 Batch 4:  cost: 0.167748
# Accuracy: 0.618
# Epoch 95, CIFAR-10 Batch 5:  cost: 0.0186333
# Accuracy: 0.621
# Epoch 96, CIFAR-10 Batch 1:  cost: 0.095769
# Accuracy: 0.6274
# Epoch 96, CIFAR-10 Batch 2:  cost: 0.0540199
# Accuracy: 0.62
# Epoch 96, CIFAR-10 Batch 3:  cost: 0.0314715
# Accuracy: 0.6288
# Epoch 96, CIFAR-10 Batch 4:  cost: 0.131392
# Accuracy: 0.6166
# Epoch 96, CIFAR-10 Batch 5:  cost: 0.0288898
# Accuracy: 0.6258
# Epoch 97, CIFAR-10 Batch 1:  cost: 0.118045
# Accuracy: 0.626
# Epoch 97, CIFAR-10 Batch 2:  cost: 0.0559721
# Accuracy: 0.615
# Epoch 97, CIFAR-10 Batch 3:  cost: 0.0241062
# Accuracy: 0.6194
# Epoch 97, CIFAR-10 Batch 4:  cost: 0.125316
# Accuracy: 0.623
# Epoch 97, CIFAR-10 Batch 5:  cost: 0.0272235
# Accuracy: 0.627
# Epoch 98, CIFAR-10 Batch 1:  cost: 0.170181
# Accuracy: 0.6292
# Epoch 98, CIFAR-10 Batch 2:  cost: 0.0511379
# Accuracy: 0.6128
# Epoch 98, CIFAR-10 Batch 3:  cost: 0.0179471
# Accuracy: 0.6214
# Epoch 98, CIFAR-10 Batch 4:  cost: 0.132397
# Accuracy: 0.6246
# Epoch 98, CIFAR-10 Batch 5:  cost: 0.0150702
# Accuracy: 0.6308
# Epoch 99, CIFAR-10 Batch 1:  cost: 0.1865
# Accuracy: 0.6298
# Epoch 99, CIFAR-10 Batch 2:  cost: 0.0770099
# Accuracy: 0.6254
# Epoch 99, CIFAR-10 Batch 3:  cost: 0.0127491
# Accuracy: 0.6316
# Epoch 99, CIFAR-10 Batch 4:  cost: 0.127533
# Accuracy: 0.616
# Epoch 99, CIFAR-10 Batch 5:  cost: 0.0322517
# Accuracy: 0.6228
# Epoch 100, CIFAR-10 Batch 1:  cost: 0.125724
# Accuracy: 0.6288
# Epoch 100, CIFAR-10 Batch 2:  cost: 0.0640121
# Accuracy: 0.6244
# Epoch 100, CIFAR-10 Batch 3:  cost: 0.0103123
# Accuracy: 0.6252
# Epoch 100, CIFAR-10 Batch 4:  cost: 0.121156
# Accuracy: 0.623
# Epoch 100, CIFAR-10 Batch 5:  cost: 0.012747
# Accuracy: 0.621
# Epoch 101, CIFAR-10 Batch 1:  cost: 0.100452
# Accuracy: 0.629
# Epoch 101, CIFAR-10 Batch 2:  cost: 0.0602144
# Accuracy: 0.6192
# Epoch 101, CIFAR-10 Batch 3:  cost: 0.0200391
# Accuracy: 0.6152
# Epoch 101, CIFAR-10 Batch 4:  cost: 0.120679
# Accuracy: 0.6176
# Epoch 101, CIFAR-10 Batch 5:  cost: 0.0169218
# Accuracy: 0.6304
# Epoch 102, CIFAR-10 Batch 1:  cost: 0.138649
# Accuracy: 0.629
# Epoch 102, CIFAR-10 Batch 2:  cost: 0.0680436
# Accuracy: 0.6144
# Epoch 102, CIFAR-10 Batch 3:  cost: 0.014242
# Accuracy: 0.6252
# Epoch 102, CIFAR-10 Batch 4:  cost: 0.121094
# Accuracy: 0.6162
# Epoch 102, CIFAR-10 Batch 5:  cost: 0.0186534
# Accuracy: 0.6132
# Epoch 103, CIFAR-10 Batch 1:  cost: 0.114427
# Accuracy: 0.6226
# Epoch 103, CIFAR-10 Batch 2:  cost: 0.0577275
# Accuracy: 0.624
# Epoch 103, CIFAR-10 Batch 3:  cost: 0.0142115
# Accuracy: 0.6318
# Epoch 103, CIFAR-10 Batch 4:  cost: 0.192525
# Accuracy: 0.62
# Epoch 103, CIFAR-10 Batch 5:  cost: 0.0126865
# Accuracy: 0.6256
# Epoch 104, CIFAR-10 Batch 1:  cost: 0.083621
# Accuracy: 0.6246
# Epoch 104, CIFAR-10 Batch 2:  cost: 0.0671726
# Accuracy: 0.635
# Epoch 104, CIFAR-10 Batch 3:  cost: 0.00942133
# Accuracy: 0.627
# Epoch 104, CIFAR-10 Batch 4:  cost: 0.114705
# Accuracy: 0.6216
# Epoch 104, CIFAR-10 Batch 5:  cost: 0.0149641
# Accuracy: 0.6124
# Epoch 105, CIFAR-10 Batch 1:  cost: 0.145916
# Accuracy: 0.6316
# Epoch 105, CIFAR-10 Batch 2:  cost: 0.054794
# Accuracy: 0.6282
# Epoch 105, CIFAR-10 Batch 3:  cost: 0.015869
# Accuracy: 0.6142
# Epoch 105, CIFAR-10 Batch 4:  cost: 0.115148
# Accuracy: 0.6218
# Epoch 105, CIFAR-10 Batch 5:  cost: 0.0288689
# Accuracy: 0.6224
# Epoch 106, CIFAR-10 Batch 1:  cost: 0.0863027
# Accuracy: 0.6274
# Epoch 106, CIFAR-10 Batch 2:  cost: 0.0509424
# Accuracy: 0.6268
# Epoch 106, CIFAR-10 Batch 3:  cost: 0.00952276
# Accuracy: 0.6228
# Epoch 106, CIFAR-10 Batch 4:  cost: 0.113345
# Accuracy: 0.6312
# Epoch 106, CIFAR-10 Batch 5:  cost: 0.0211788
# Accuracy: 0.6318
# Epoch 107, CIFAR-10 Batch 1:  cost: 0.113992
# Accuracy: 0.6268
# Epoch 107, CIFAR-10 Batch 2:  cost: 0.0809601
# Accuracy: 0.6242
# Epoch 107, CIFAR-10 Batch 3:  cost: 0.0399935
# Accuracy: 0.6202
# Epoch 107, CIFAR-10 Batch 4:  cost: 0.115756
# Accuracy: 0.6276
# Epoch 107, CIFAR-10 Batch 5:  cost: 0.0110306
# Accuracy: 0.6282
# Epoch 108, CIFAR-10 Batch 1:  cost: 0.0889685
# Accuracy: 0.6208
# Epoch 108, CIFAR-10 Batch 2:  cost: 0.0568366
# Accuracy: 0.6192
# Epoch 108, CIFAR-10 Batch 3:  cost: 0.0116705
# Accuracy: 0.6202
# Epoch 108, CIFAR-10 Batch 4:  cost: 0.112501
# Accuracy: 0.6228
# Epoch 108, CIFAR-10 Batch 5:  cost: 0.0213839
# Accuracy: 0.6268
# Epoch 109, CIFAR-10 Batch 1:  cost: 0.096932
# Accuracy: 0.6314
# Epoch 109, CIFAR-10 Batch 2:  cost: 0.0622422
# Accuracy: 0.6226
# Epoch 109, CIFAR-10 Batch 3:  cost: 0.0892766
# Accuracy: 0.626
# Epoch 109, CIFAR-10 Batch 4:  cost: 0.105812
# Accuracy: 0.6284
# Epoch 109, CIFAR-10 Batch 5:  cost: 0.0173769
# Accuracy: 0.6256
# Epoch 110, CIFAR-10 Batch 1:  cost: 0.15682
# Accuracy: 0.634
# Epoch 110, CIFAR-10 Batch 2:  cost: 0.0922234
# Accuracy: 0.6182
# Epoch 110, CIFAR-10 Batch 3:  cost: 0.0898891
# Accuracy: 0.619
# Epoch 110, CIFAR-10 Batch 4:  cost: 0.115857
# Accuracy: 0.6242
# Epoch 110, CIFAR-10 Batch 5:  cost: 0.0216053
# Accuracy: 0.629
# Epoch 111, CIFAR-10 Batch 1:  cost: 0.11432
# Accuracy: 0.6246
# Epoch 111, CIFAR-10 Batch 2:  cost: 0.0830925
# Accuracy: 0.6282
# Epoch 111, CIFAR-10 Batch 3:  cost: 0.0546981
# Accuracy: 0.6316
# Epoch 111, CIFAR-10 Batch 4:  cost: 0.108066
# Accuracy: 0.6294
# Epoch 111, CIFAR-10 Batch 5:  cost: 0.0183557
# Accuracy: 0.6276
# Epoch 112, CIFAR-10 Batch 1:  cost: 0.0914859
# Accuracy: 0.6208
# Epoch 112, CIFAR-10 Batch 2:  cost: 0.0616527
# Accuracy: 0.626
# Epoch 112, CIFAR-10 Batch 3:  cost: 0.00737046
# Accuracy: 0.6372
# Epoch 112, CIFAR-10 Batch 4:  cost: 0.107013
# Accuracy: 0.621
# Epoch 112, CIFAR-10 Batch 5:  cost: 0.00992234
# Accuracy: 0.631
# Epoch 113, CIFAR-10 Batch 1:  cost: 0.0907651
# Accuracy: 0.6252
# Epoch 113, CIFAR-10 Batch 2:  cost: 0.054792
# Accuracy: 0.6302
# Epoch 113, CIFAR-10 Batch 3:  cost: 0.0117018
# Accuracy: 0.6232
# Epoch 113, CIFAR-10 Batch 4:  cost: 0.0975262
# Accuracy: 0.6294
# Epoch 113, CIFAR-10 Batch 5:  cost: 0.0155669
# Accuracy: 0.6256
# Epoch 114, CIFAR-10 Batch 1:  cost: 0.0870251
# Accuracy: 0.6262
# Epoch 114, CIFAR-10 Batch 2:  cost: 0.0439149
# Accuracy: 0.6282
# Epoch 114, CIFAR-10 Batch 3:  cost: 0.0502531
# Accuracy: 0.629
# Epoch 114, CIFAR-10 Batch 4:  cost: 0.101153
# Accuracy: 0.6242
# Epoch 114, CIFAR-10 Batch 5:  cost: 0.00752057
# Accuracy: 0.6342
# Epoch 115, CIFAR-10 Batch 1:  cost: 0.11925
# Accuracy: 0.6316
# Epoch 115, CIFAR-10 Batch 2:  cost: 0.0482871
# Accuracy: 0.6252
# Epoch 115, CIFAR-10 Batch 3:  cost: 0.01056
# Accuracy: 0.6164
# Epoch 115, CIFAR-10 Batch 4:  cost: 0.106527
# Accuracy: 0.618
# Epoch 115, CIFAR-10 Batch 5:  cost: 0.00851687
# Accuracy: 0.6268
# Epoch 116, CIFAR-10 Batch 1:  cost: 0.0912921
# Accuracy: 0.6208
# Epoch 116, CIFAR-10 Batch 2:  cost: 0.0548862
# Accuracy: 0.6254
# Epoch 116, CIFAR-10 Batch 3:  cost: 0.0156124
# Accuracy: 0.633
# Epoch 116, CIFAR-10 Batch 4:  cost: 0.0992497
# Accuracy: 0.6148
# Epoch 116, CIFAR-10 Batch 5:  cost: 0.0200108
# Accuracy: 0.6342
# Epoch 117, CIFAR-10 Batch 1:  cost: 0.114463
# Accuracy: 0.6328
# Epoch 117, CIFAR-10 Batch 2:  cost: 0.0580457
# Accuracy: 0.6246
# Epoch 117, CIFAR-10 Batch 3:  cost: 0.0238526
# Accuracy: 0.6268
# Epoch 117, CIFAR-10 Batch 4:  cost: 0.103225
# Accuracy: 0.6272
# Epoch 117, CIFAR-10 Batch 5:  cost: 0.142329
# Accuracy: 0.6368
# Epoch 118, CIFAR-10 Batch 1:  cost: 0.109217
# Accuracy: 0.6326
# Epoch 118, CIFAR-10 Batch 2:  cost: 0.0541147
# Accuracy: 0.632
# Epoch 118, CIFAR-10 Batch 3:  cost: 0.0286794
# Accuracy: 0.6244
# Epoch 118, CIFAR-10 Batch 4:  cost: 0.0988612
# Accuracy: 0.6286
# Epoch 118, CIFAR-10 Batch 5:  cost: 0.0326789
# Accuracy: 0.6346
# Epoch 119, CIFAR-10 Batch 1:  cost: 0.149781
# Accuracy: 0.632
# Epoch 119, CIFAR-10 Batch 2:  cost: 0.0443631
# Accuracy: 0.6236
# Epoch 119, CIFAR-10 Batch 3:  cost: 0.0098885
# Accuracy: 0.6276
# Epoch 119, CIFAR-10 Batch 4:  cost: 0.103888
# Accuracy: 0.629
# Epoch 119, CIFAR-10 Batch 5:  cost: 0.0147054
# Accuracy: 0.6306
# Epoch 120, CIFAR-10 Batch 1:  cost: 0.093873
# Accuracy: 0.632
# Epoch 120, CIFAR-10 Batch 2:  cost: 0.0267216
# Accuracy: 0.6332
# Epoch 120, CIFAR-10 Batch 3:  cost: 0.0131303
# Accuracy: 0.6236
# Epoch 120, CIFAR-10 Batch 4:  cost: 0.0951562
# Accuracy: 0.633
# Epoch 120, CIFAR-10 Batch 5:  cost: 0.0114661
# Accuracy: 0.628
# Epoch 121, CIFAR-10 Batch 1:  cost: 0.092375
# Accuracy: 0.6342
# Epoch 121, CIFAR-10 Batch 2:  cost: 0.0173843
# Accuracy: 0.62
# Epoch 121, CIFAR-10 Batch 3:  cost: 0.0101038
# Accuracy: 0.6298
# Epoch 121, CIFAR-10 Batch 4:  cost: 0.100702
# Accuracy: 0.6298
# Epoch 121, CIFAR-10 Batch 5:  cost: 0.0131917
# Accuracy: 0.6354
# Epoch 122, CIFAR-10 Batch 1:  cost: 0.0878913
# Accuracy: 0.634
# Epoch 122, CIFAR-10 Batch 2:  cost: 0.0262521
# Accuracy: 0.6242
# Epoch 122, CIFAR-10 Batch 3:  cost: 0.0110219
# Accuracy: 0.6292
# Epoch 122, CIFAR-10 Batch 4:  cost: 0.104632
# Accuracy: 0.6236
# Epoch 122, CIFAR-10 Batch 5:  cost: 0.0161454
# Accuracy: 0.6208
# Epoch 123, CIFAR-10 Batch 1:  cost: 0.0965834
# Accuracy: 0.6272
# Epoch 123, CIFAR-10 Batch 2:  cost: 0.0389133
# Accuracy: 0.6256
# Epoch 123, CIFAR-10 Batch 3:  cost: 0.00763698
# Accuracy: 0.6282
# Epoch 123, CIFAR-10 Batch 4:  cost: 0.105383
# Accuracy: 0.626
# Epoch 123, CIFAR-10 Batch 5:  cost: 0.00812292
# Accuracy: 0.6342
# Epoch 124, CIFAR-10 Batch 1:  cost: 0.098611
# Accuracy: 0.63
# Epoch 124, CIFAR-10 Batch 2:  cost: 0.0428939
# Accuracy: 0.6298
# Epoch 124, CIFAR-10 Batch 3:  cost: 0.0186864
# Accuracy: 0.6298
# Epoch 124, CIFAR-10 Batch 4:  cost: 0.110857
# Accuracy: 0.6244
# Epoch 124, CIFAR-10 Batch 5:  cost: 0.00851187
# Accuracy: 0.6262
# Epoch 125, CIFAR-10 Batch 1:  cost: 0.0929027
# Accuracy: 0.622
# Epoch 125, CIFAR-10 Batch 2:  cost: 0.0581804
# Accuracy: 0.6268
# Epoch 125, CIFAR-10 Batch 3:  cost: 0.0110894
# Accuracy: 0.6252
# Epoch 125, CIFAR-10 Batch 4:  cost: 0.106006
# Accuracy: 0.6258
# Epoch 125, CIFAR-10 Batch 5:  cost: 0.0172943
# Accuracy: 0.618
# Epoch 126, CIFAR-10 Batch 1:  cost: 0.088051
# Accuracy: 0.6254
# Epoch 126, CIFAR-10 Batch 2:  cost: 0.146644
# Accuracy: 0.6264
# Epoch 126, CIFAR-10 Batch 3:  cost: 0.00839972
# Accuracy: 0.6292
# Epoch 126, CIFAR-10 Batch 4:  cost: 0.105512
# Accuracy: 0.6262
# Epoch 126, CIFAR-10 Batch 5:  cost: 0.0222372
# Accuracy: 0.628
# Epoch 127, CIFAR-10 Batch 1:  cost: 0.112735
# Accuracy: 0.6314
# Epoch 127, CIFAR-10 Batch 2:  cost: 0.0456647
# Accuracy: 0.6334
# Epoch 127, CIFAR-10 Batch 3:  cost: 0.00620943
# Accuracy: 0.6288
# Epoch 127, CIFAR-10 Batch 4:  cost: 0.103625
# Accuracy: 0.6254
# Epoch 127, CIFAR-10 Batch 5:  cost: 0.010553
# Accuracy: 0.6324
# Epoch 128, CIFAR-10 Batch 1:  cost: 0.106259
# Accuracy: 0.6236
# Epoch 128, CIFAR-10 Batch 2:  cost: 0.0456526
# Accuracy: 0.6184
# Epoch 128, CIFAR-10 Batch 3:  cost: 0.0068894
# Accuracy: 0.6328
# Epoch 128, CIFAR-10 Batch 4:  cost: 0.105068
# Accuracy: 0.6258
# Epoch 128, CIFAR-10 Batch 5:  cost: 0.0103715
# Accuracy: 0.6268
# Epoch 129, CIFAR-10 Batch 1:  cost: 0.109824
# Accuracy: 0.6322
# Epoch 129, CIFAR-10 Batch 2:  cost: 0.0343707
# Accuracy: 0.6202
# Epoch 129, CIFAR-10 Batch 3:  cost: 0.0063063
# Accuracy: 0.6266
# Epoch 129, CIFAR-10 Batch 4:  cost: 0.103222
# Accuracy: 0.6218
# Epoch 129, CIFAR-10 Batch 5:  cost: 0.00677093
# Accuracy: 0.6276
# Epoch 130, CIFAR-10 Batch 1:  cost: 0.107261
# Accuracy: 0.626
# Epoch 130, CIFAR-10 Batch 2:  cost: 0.0452233
# Accuracy: 0.6226
# Epoch 130, CIFAR-10 Batch 3:  cost: 0.00644141
# Accuracy: 0.631
# Epoch 130, CIFAR-10 Batch 4:  cost: 0.100938
# Accuracy: 0.6212
# Epoch 130, CIFAR-10 Batch 5:  cost: 0.0108144
# Accuracy: 0.6338
# Epoch 131, CIFAR-10 Batch 1:  cost: 0.10927
# Accuracy: 0.6262
# Epoch 131, CIFAR-10 Batch 2:  cost: 0.0345262
# Accuracy: 0.6302
# Epoch 131, CIFAR-10 Batch 3:  cost: 0.0778978
# Accuracy: 0.6256
# Epoch 131, CIFAR-10 Batch 4:  cost: 0.100938
# Accuracy: 0.627
# Epoch 131, CIFAR-10 Batch 5:  cost: 0.0153231
# Accuracy: 0.6306
# Epoch 132, CIFAR-10 Batch 1:  cost: 0.106656
# Accuracy: 0.6314
# Epoch 132, CIFAR-10 Batch 2:  cost: 0.0458571
# Accuracy: 0.629
# Epoch 132, CIFAR-10 Batch 3:  cost: 0.00611189
# Accuracy: 0.6308
# Epoch 132, CIFAR-10 Batch 4:  cost: 0.104513
# Accuracy: 0.622
# Epoch 132, CIFAR-10 Batch 5:  cost: 0.00854919
# Accuracy: 0.6306
# Epoch 133, CIFAR-10 Batch 1:  cost: 0.120477
# Accuracy: 0.6374
# Epoch 133, CIFAR-10 Batch 2:  cost: 0.043141
# Accuracy: 0.634
# Epoch 133, CIFAR-10 Batch 3:  cost: 0.00659169
# Accuracy: 0.6398
# Epoch 133, CIFAR-10 Batch 4:  cost: 0.100815
# Accuracy: 0.6262
# Epoch 133, CIFAR-10 Batch 5:  cost: 0.00799522
# Accuracy: 0.6234
# Epoch 134, CIFAR-10 Batch 1:  cost: 0.0960273
# Accuracy: 0.628
# Epoch 134, CIFAR-10 Batch 2:  cost: 0.0538508
# Accuracy: 0.6312
# Epoch 134, CIFAR-10 Batch 3:  cost: 0.00555273
# Accuracy: 0.6294
# Epoch 134, CIFAR-10 Batch 4:  cost: 0.124135
# Accuracy: 0.6238
# Epoch 134, CIFAR-10 Batch 5:  cost: 0.00605285
# Accuracy: 0.633
# Epoch 135, CIFAR-10 Batch 1:  cost: 0.108293
# Accuracy: 0.6292
# Epoch 135, CIFAR-10 Batch 2:  cost: 0.0528977
# Accuracy: 0.6256
# Epoch 135, CIFAR-10 Batch 3:  cost: 0.0374959
# Accuracy: 0.6334
# Epoch 135, CIFAR-10 Batch 4:  cost: 0.0927504
# Accuracy: 0.6314
# Epoch 135, CIFAR-10 Batch 5:  cost: 0.00836654
# Accuracy: 0.6306
# Epoch 136, CIFAR-10 Batch 1:  cost: 0.165176
# Accuracy: 0.6372
# Epoch 136, CIFAR-10 Batch 2:  cost: 0.0183253
# Accuracy: 0.619
# Epoch 136, CIFAR-10 Batch 3:  cost: 0.00787258
# Accuracy: 0.6336
# Epoch 136, CIFAR-10 Batch 4:  cost: 0.0925849
# Accuracy: 0.6264
# Epoch 136, CIFAR-10 Batch 5:  cost: 0.00710091
# Accuracy: 0.6254
# Epoch 137, CIFAR-10 Batch 1:  cost: 0.105827
# Accuracy: 0.6276
# Epoch 137, CIFAR-10 Batch 2:  cost: 0.0151711
# Accuracy: 0.6326
# Epoch 137, CIFAR-10 Batch 3:  cost: 0.00438311
# Accuracy: 0.638
# Epoch 137, CIFAR-10 Batch 4:  cost: 0.0979097
# Accuracy: 0.6352
# Epoch 137, CIFAR-10 Batch 5:  cost: 0.00912545
# Accuracy: 0.6296
# Epoch 138, CIFAR-10 Batch 1:  cost: 0.102972
# Accuracy: 0.6304
# Epoch 138, CIFAR-10 Batch 2:  cost: 0.0152456
# Accuracy: 0.6238
# Epoch 138, CIFAR-10 Batch 3:  cost: 0.00812029
# Accuracy: 0.6368
# Epoch 138, CIFAR-10 Batch 4:  cost: 0.0991068
# Accuracy: 0.6312
# Epoch 138, CIFAR-10 Batch 5:  cost: 0.00905211
# Accuracy: 0.6338
# Epoch 139, CIFAR-10 Batch 1:  cost: 0.101772
# Accuracy: 0.627
# Epoch 139, CIFAR-10 Batch 2:  cost: 0.0145237
# Accuracy: 0.6286
# Epoch 139, CIFAR-10 Batch 3:  cost: 0.0076185
# Accuracy: 0.6298
# Epoch 139, CIFAR-10 Batch 4:  cost: 0.100877
# Accuracy: 0.6326
# Epoch 139, CIFAR-10 Batch 5:  cost: 0.00842097
# Accuracy: 0.6334
# Epoch 140, CIFAR-10 Batch 1:  cost: 0.10261
# Accuracy: 0.6264
# Epoch 140, CIFAR-10 Batch 2:  cost: 0.079526
# Accuracy: 0.6288
# Epoch 140, CIFAR-10 Batch 3:  cost: 0.00727661
# Accuracy: 0.6282
# Epoch 140, CIFAR-10 Batch 4:  cost: 0.100055
# Accuracy: 0.6304
# Epoch 140, CIFAR-10 Batch 5:  cost: 0.0184292
# Accuracy: 0.6336
# Epoch 141, CIFAR-10 Batch 1:  cost: 0.102441
# Accuracy: 0.6372
# Epoch 141, CIFAR-10 Batch 2:  cost: 0.0370417
# Accuracy: 0.6326
# Epoch 141, CIFAR-10 Batch 3:  cost: 0.00626456
# Accuracy: 0.6372
# Epoch 141, CIFAR-10 Batch 4:  cost: 0.0947161
# Accuracy: 0.634
# Epoch 141, CIFAR-10 Batch 5:  cost: 0.0122235
# Accuracy: 0.6348
# Epoch 142, CIFAR-10 Batch 1:  cost: 0.117893
# Accuracy: 0.6264
# Epoch 142, CIFAR-10 Batch 2:  cost: 0.0784923
# Accuracy: 0.6232
# Epoch 142, CIFAR-10 Batch 3:  cost: 0.00966596
# Accuracy: 0.6272
# Epoch 142, CIFAR-10 Batch 4:  cost: 0.09789
# Accuracy: 0.6278
# Epoch 142, CIFAR-10 Batch 5:  cost: 0.00983176
# Accuracy: 0.6282
# Epoch 143, CIFAR-10 Batch 1:  cost: 0.106302
# Accuracy: 0.631
# Epoch 143, CIFAR-10 Batch 2:  cost: 0.0457176
# Accuracy: 0.6266
# Epoch 143, CIFAR-10 Batch 3:  cost: 0.0215347
# Accuracy: 0.63
# Epoch 143, CIFAR-10 Batch 4:  cost: 0.155399
# Accuracy: 0.6298
# Epoch 143, CIFAR-10 Batch 5:  cost: 0.0797094
# Accuracy: 0.6298
# Epoch 144, CIFAR-10 Batch 1:  cost: 0.116624
# Accuracy: 0.6364
# Epoch 144, CIFAR-10 Batch 2:  cost: 0.0412602
# Accuracy: 0.6338
# Epoch 144, CIFAR-10 Batch 3:  cost: 0.0121938
# Accuracy: 0.629
# Epoch 144, CIFAR-10 Batch 4:  cost: 0.0939426
# Accuracy: 0.6286
# Epoch 144, CIFAR-10 Batch 5:  cost: 0.00716226
# Accuracy: 0.6338
# Epoch 145, CIFAR-10 Batch 1:  cost: 0.107782
# Accuracy: 0.6352
# Epoch 145, CIFAR-10 Batch 2:  cost: 0.0452235
# Accuracy: 0.6326
# Epoch 145, CIFAR-10 Batch 3:  cost: 0.00653815
# Accuracy: 0.6318
# Epoch 145, CIFAR-10 Batch 4:  cost: 0.0972006
# Accuracy: 0.6314
# Epoch 145, CIFAR-10 Batch 5:  cost: 0.00411082
# Accuracy: 0.6404
# Epoch 146, CIFAR-10 Batch 1:  cost: 0.106257
# Accuracy: 0.6302
# Epoch 146, CIFAR-10 Batch 2:  cost: 0.0308981
# Accuracy: 0.6226
# Epoch 146, CIFAR-10 Batch 3:  cost: 0.00331632
# Accuracy: 0.6318
# Epoch 146, CIFAR-10 Batch 4:  cost: 0.0918847
# Accuracy: 0.6332
# Epoch 146, CIFAR-10 Batch 5:  cost: 0.00477142
# Accuracy: 0.634
# Epoch 147, CIFAR-10 Batch 1:  cost: 0.0936482
# Accuracy: 0.6368
# Epoch 147, CIFAR-10 Batch 2:  cost: 0.0124883
# Accuracy: 0.6286
# Epoch 147, CIFAR-10 Batch 3:  cost: 0.0120024
# Accuracy: 0.6226
# Epoch 147, CIFAR-10 Batch 4:  cost: 0.0948206
# Accuracy: 0.635
# Epoch 147, CIFAR-10 Batch 5:  cost: 0.0104174
# Accuracy: 0.634
# Epoch 148, CIFAR-10 Batch 1:  cost: 0.0708975
# Accuracy: 0.6368
# Epoch 148, CIFAR-10 Batch 2:  cost: 0.0062062
# Accuracy: 0.6284
# Epoch 148, CIFAR-10 Batch 3:  cost: 0.00526222
# Accuracy: 0.635
# Epoch 148, CIFAR-10 Batch 4:  cost: 0.0911837
# Accuracy: 0.6308
# Epoch 148, CIFAR-10 Batch 5:  cost: 0.00452801
# Accuracy: 0.6308
# Epoch 149, CIFAR-10 Batch 1:  cost: 0.0652971
# Accuracy: 0.6386
# Epoch 149, CIFAR-10 Batch 2:  cost: 0.00378405
# Accuracy: 0.6296
# Epoch 149, CIFAR-10 Batch 3:  cost: 0.00941626
# Accuracy: 0.639
# Epoch 149, CIFAR-10 Batch 4:  cost: 0.0935083
# Accuracy: 0.6334
# Epoch 149, CIFAR-10 Batch 5:  cost: 0.00356357
# Accuracy: 0.6354
# Epoch 150, CIFAR-10 Batch 1:  cost: 0.0495268
# Accuracy: 0.636
# Epoch 150, CIFAR-10 Batch 2:  cost: 0.00723449
# Accuracy: 0.6336
# Epoch 150, CIFAR-10 Batch 3:  cost: 0.00520709
# Accuracy: 0.6356
# Epoch 150, CIFAR-10 Batch 4:  cost: 0.0954502
# Accuracy: 0.6248
# Epoch 150, CIFAR-10 Batch 5:  cost: 0.00772501
# Accuracy: 0.6248
# Epoch 151, CIFAR-10 Batch 1:  cost: 0.0297443
# Accuracy: 0.6326
# Epoch 151, CIFAR-10 Batch 2:  cost: 0.0107949
# Accuracy: 0.6292
# Epoch 151, CIFAR-10 Batch 3:  cost: 0.0685842
# Accuracy: 0.6314
# Epoch 151, CIFAR-10 Batch 4:  cost: 0.0906894
# Accuracy: 0.6228
# Epoch 151, CIFAR-10 Batch 5:  cost: 0.00970746
# Accuracy: 0.6224
# Epoch 152, CIFAR-10 Batch 1:  cost: 0.0355374
# Accuracy: 0.6246
# Epoch 152, CIFAR-10 Batch 2:  cost: 0.0329742
# Accuracy: 0.6266
# Epoch 152, CIFAR-10 Batch 3:  cost: 0.00712379
# Accuracy: 0.631
# Epoch 152, CIFAR-10 Batch 4:  cost: 0.0954857
# Accuracy: 0.6284
# Epoch 152, CIFAR-10 Batch 5:  cost: 0.00535545
# Accuracy: 0.6308
# Epoch 153, CIFAR-10 Batch 1:  cost: 0.0302347
# Accuracy: 0.6286
# Epoch 153, CIFAR-10 Batch 2:  cost: 0.00569579
# Accuracy: 0.627
# Epoch 153, CIFAR-10 Batch 3:  cost: 0.00631903
# Accuracy: 0.6252
# Epoch 153, CIFAR-10 Batch 4:  cost: 0.0931755
# Accuracy: 0.626
# Epoch 153, CIFAR-10 Batch 5:  cost: 0.00446486
# Accuracy: 0.6288
# Epoch 154, CIFAR-10 Batch 1:  cost: 0.0306023
# Accuracy: 0.6304
# Epoch 154, CIFAR-10 Batch 2:  cost: 0.00601671
# Accuracy: 0.6286
# Epoch 154, CIFAR-10 Batch 3:  cost: 0.00373871
# Accuracy: 0.628
# Epoch 154, CIFAR-10 Batch 4:  cost: 0.0935476
# Accuracy: 0.628
# Epoch 154, CIFAR-10 Batch 5:  cost: 0.00485516
# Accuracy: 0.633
# Epoch 155, CIFAR-10 Batch 1:  cost: 0.0649493
# Accuracy: 0.626
# Epoch 155, CIFAR-10 Batch 2:  cost: 0.00317135
# Accuracy: 0.6312
# Epoch 155, CIFAR-10 Batch 3:  cost: 0.00436699
# Accuracy: 0.6298
# Epoch 155, CIFAR-10 Batch 4:  cost: 0.0855894
# Accuracy: 0.6238
# Epoch 155, CIFAR-10 Batch 5:  cost: 0.00451654
# Accuracy: 0.6276
# Epoch 156, CIFAR-10 Batch 1:  cost: 0.0638407
# Accuracy: 0.6262
# Epoch 156, CIFAR-10 Batch 2:  cost: 0.0123787
# Accuracy: 0.6294
# Epoch 156, CIFAR-10 Batch 3:  cost: 0.0125143
# Accuracy: 0.6196
# Epoch 156, CIFAR-10 Batch 4:  cost: 0.113683
# Accuracy: 0.6188
# Epoch 156, CIFAR-10 Batch 5:  cost: 0.0208429
# Accuracy: 0.628
# Epoch 157, CIFAR-10 Batch 1:  cost: 0.0622883
# Accuracy: 0.6314
# Epoch 157, CIFAR-10 Batch 2:  cost: 0.00566696
# Accuracy: 0.6258
# Epoch 157, CIFAR-10 Batch 3:  cost: 0.00970088
# Accuracy: 0.6268
# Epoch 157, CIFAR-10 Batch 4:  cost: 0.101381
# Accuracy: 0.629
# Epoch 157, CIFAR-10 Batch 5:  cost: 0.00747508
# Accuracy: 0.6298
# Epoch 158, CIFAR-10 Batch 1:  cost: 0.0610324
# Accuracy: 0.6236
# Epoch 158, CIFAR-10 Batch 2:  cost: 0.00313682
# Accuracy: 0.6258
# Epoch 158, CIFAR-10 Batch 3:  cost: 0.0275095
# Accuracy: 0.6244
# Epoch 158, CIFAR-10 Batch 4:  cost: 0.103087
# Accuracy: 0.6296
# Epoch 158, CIFAR-10 Batch 5:  cost: 0.00470683
# Accuracy: 0.629
# Epoch 159, CIFAR-10 Batch 1:  cost: 0.0593171
# Accuracy: 0.6418
# Epoch 159, CIFAR-10 Batch 2:  cost: 0.00430808
# Accuracy: 0.6326
# Epoch 159, CIFAR-10 Batch 3:  cost: 0.00403232
# Accuracy: 0.631
# Epoch 159, CIFAR-10 Batch 4:  cost: 0.0883552
# Accuracy: 0.6288
# Epoch 159, CIFAR-10 Batch 5:  cost: 0.0169736
# Accuracy: 0.6312
# Epoch 160, CIFAR-10 Batch 1:  cost: 0.0565023
# Accuracy: 0.6308
# Epoch 160, CIFAR-10 Batch 2:  cost: 0.00859029
# Accuracy: 0.6282
# Epoch 160, CIFAR-10 Batch 3:  cost: 0.00906629
# Accuracy: 0.628
# Epoch 160, CIFAR-10 Batch 4:  cost: 0.0917278
# Accuracy: 0.628
# Epoch 160, CIFAR-10 Batch 5:  cost: 0.00429784
# Accuracy: 0.6264
# Epoch 161, CIFAR-10 Batch 1:  cost: 0.0668215
# Accuracy: 0.6268
# Epoch 161, CIFAR-10 Batch 2:  cost: 0.0151455
# Accuracy: 0.6286
# Epoch 161, CIFAR-10 Batch 3:  cost: 0.00474666
# Accuracy: 0.629
# Epoch 161, CIFAR-10 Batch 4:  cost: 0.0916158
# Accuracy: 0.631
# Epoch 161, CIFAR-10 Batch 5:  cost: 0.00592933
# Accuracy: 0.627
# Epoch 162, CIFAR-10 Batch 1:  cost: 0.0613933
# Accuracy: 0.6324
# Epoch 162, CIFAR-10 Batch 2:  cost: 0.00413503
# Accuracy: 0.6262
# Epoch 162, CIFAR-10 Batch 3:  cost: 0.00808251
# Accuracy: 0.6274
# Epoch 162, CIFAR-10 Batch 4:  cost: 0.0955253
# Accuracy: 0.6364
# Epoch 162, CIFAR-10 Batch 5:  cost: 0.0194727
# Accuracy: 0.6252
# Epoch 163, CIFAR-10 Batch 1:  cost: 0.0635008
# Accuracy: 0.6332
# Epoch 163, CIFAR-10 Batch 2:  cost: 0.00299746
# Accuracy: 0.6326
# Epoch 163, CIFAR-10 Batch 3:  cost: 0.0061874
# Accuracy: 0.6312
# Epoch 163, CIFAR-10 Batch 4:  cost: 0.0892774
# Accuracy: 0.6304
# Epoch 163, CIFAR-10 Batch 5:  cost: 0.00805751
# Accuracy: 0.6214
# Epoch 164, CIFAR-10 Batch 1:  cost: 0.0582171
# Accuracy: 0.6408
# Epoch 164, CIFAR-10 Batch 2:  cost: 0.00374768
# Accuracy: 0.634
# Epoch 164, CIFAR-10 Batch 3:  cost: 0.00624667
# Accuracy: 0.6358
# Epoch 164, CIFAR-10 Batch 4:  cost: 0.0886391
# Accuracy: 0.6344
# Epoch 164, CIFAR-10 Batch 5:  cost: 0.00463536
# Accuracy: 0.63
# Epoch 165, CIFAR-10 Batch 1:  cost: 0.0594391
# Accuracy: 0.6308
# Epoch 165, CIFAR-10 Batch 2:  cost: 0.0034682
# Accuracy: 0.63
# Epoch 165, CIFAR-10 Batch 3:  cost: 0.00438972
# Accuracy: 0.6334
# Epoch 165, CIFAR-10 Batch 4:  cost: 0.0898822
# Accuracy: 0.6254
# Epoch 165, CIFAR-10 Batch 5:  cost: 0.0134438
# Accuracy: 0.6282
# Epoch 166, CIFAR-10 Batch 1:  cost: 0.0583864
# Accuracy: 0.637
# Epoch 166, CIFAR-10 Batch 2:  cost: 0.00535373
# Accuracy: 0.6362
# Epoch 166, CIFAR-10 Batch 3:  cost: 0.00347463
# Accuracy: 0.6348
# Epoch 166, CIFAR-10 Batch 4:  cost: 0.0906385
# Accuracy: 0.6396
# Epoch 166, CIFAR-10 Batch 5:  cost: 0.00574756
# Accuracy: 0.6354
# Epoch 167, CIFAR-10 Batch 1:  cost: 0.05661
# Accuracy: 0.6404
# Epoch 167, CIFAR-10 Batch 2:  cost: 0.00482025
# Accuracy: 0.636
# Epoch 167, CIFAR-10 Batch 3:  cost: 0.00486805
# Accuracy: 0.6418
# Epoch 167, CIFAR-10 Batch 4:  cost: 0.0912092
# Accuracy: 0.636
# Epoch 167, CIFAR-10 Batch 5:  cost: 0.00340257
# Accuracy: 0.6344
# Epoch 168, CIFAR-10 Batch 1:  cost: 0.0307584
# Accuracy: 0.6388
# Epoch 168, CIFAR-10 Batch 2:  cost: 0.0165051
# Accuracy: 0.6296
# Epoch 168, CIFAR-10 Batch 3:  cost: 0.00639296
# Accuracy: 0.632
# Epoch 168, CIFAR-10 Batch 4:  cost: 0.0872381
# Accuracy: 0.64
# Epoch 168, CIFAR-10 Batch 5:  cost: 0.00427618
# Accuracy: 0.6408
# Epoch 169, CIFAR-10 Batch 1:  cost: 0.0291833
# Accuracy: 0.635
# Epoch 169, CIFAR-10 Batch 2:  cost: 0.00424199
# Accuracy: 0.6228
# Epoch 169, CIFAR-10 Batch 3:  cost: 0.0042087
# Accuracy: 0.6334
# Epoch 169, CIFAR-10 Batch 4:  cost: 0.0895154
# Accuracy: 0.6338
# Epoch 169, CIFAR-10 Batch 5:  cost: 0.00440733
# Accuracy: 0.6322
# Epoch 170, CIFAR-10 Batch 1:  cost: 0.0297444
# Accuracy: 0.64
# Epoch 170, CIFAR-10 Batch 2:  cost: 0.00711615
# Accuracy: 0.6252
# Epoch 170, CIFAR-10 Batch 3:  cost: 0.00903151
# Accuracy: 0.6328
# Epoch 170, CIFAR-10 Batch 4:  cost: 0.0865859
# Accuracy: 0.6302
# Epoch 170, CIFAR-10 Batch 5:  cost: 0.00437841
# Accuracy: 0.6292
# Epoch 171, CIFAR-10 Batch 1:  cost: 0.0418298
# Accuracy: 0.6302
# Epoch 171, CIFAR-10 Batch 2:  cost: 0.00951836
# Accuracy: 0.6378
# Epoch 171, CIFAR-10 Batch 3:  cost: 0.00624192
# Accuracy: 0.6294
# Epoch 171, CIFAR-10 Batch 4:  cost: 0.0903854
# Accuracy: 0.6294
# Epoch 171, CIFAR-10 Batch 5:  cost: 0.00456746
# Accuracy: 0.6294
# Epoch 172, CIFAR-10 Batch 1:  cost: 0.0567367
# Accuracy: 0.6358
# Epoch 172, CIFAR-10 Batch 2:  cost: 0.00842884
# Accuracy: 0.6322
# Epoch 172, CIFAR-10 Batch 3:  cost: 0.00456957
# Accuracy: 0.6272
# Epoch 172, CIFAR-10 Batch 4:  cost: 0.0917284
# Accuracy: 0.625
# Epoch 172, CIFAR-10 Batch 5:  cost: 0.00346464
# Accuracy: 0.6322
# Epoch 173, CIFAR-10 Batch 1:  cost: 0.0202648
# Accuracy: 0.6238
# Epoch 173, CIFAR-10 Batch 2:  cost: 0.00408654
# Accuracy: 0.622
# Epoch 173, CIFAR-10 Batch 3:  cost: 0.00366026
# Accuracy: 0.6288
# Epoch 173, CIFAR-10 Batch 4:  cost: 0.0884898
# Accuracy: 0.6268
# Epoch 173, CIFAR-10 Batch 5:  cost: 0.0119491
# Accuracy: 0.6232
# Epoch 174, CIFAR-10 Batch 1:  cost: 0.0301062
# Accuracy: 0.632
# Epoch 174, CIFAR-10 Batch 2:  cost: 0.00264636
# Accuracy: 0.6198
# Epoch 174, CIFAR-10 Batch 3:  cost: 0.00394848
# Accuracy: 0.6212
# Epoch 174, CIFAR-10 Batch 4:  cost: 0.0900692
# Accuracy: 0.6236
# Epoch 174, CIFAR-10 Batch 5:  cost: 0.00487656
# Accuracy: 0.6346
# Epoch 175, CIFAR-10 Batch 1:  cost: 0.0419944
# Accuracy: 0.6276
# Epoch 175, CIFAR-10 Batch 2:  cost: 0.00342846
# Accuracy: 0.6166
# Epoch 175, CIFAR-10 Batch 3:  cost: 0.00283181
# Accuracy: 0.6302
# Epoch 175, CIFAR-10 Batch 4:  cost: 0.0912644
# Accuracy: 0.619
# Epoch 175, CIFAR-10 Batch 5:  cost: 0.00550572
# Accuracy: 0.63
# Epoch 176, CIFAR-10 Batch 1:  cost: 0.0309282
# Accuracy: 0.6284
# Epoch 176, CIFAR-10 Batch 2:  cost: 0.00481266
# Accuracy: 0.6344
# Epoch 176, CIFAR-10 Batch 3:  cost: 0.00335117
# Accuracy: 0.6352
# Epoch 176, CIFAR-10 Batch 4:  cost: 0.0880892
# Accuracy: 0.6292
# Epoch 176, CIFAR-10 Batch 5:  cost: 0.00381651
# Accuracy: 0.6318
# Epoch 177, CIFAR-10 Batch 1:  cost: 0.0201075
# Accuracy: 0.6356
# Epoch 177, CIFAR-10 Batch 2:  cost: 0.0056325
# Accuracy: 0.6278
# Epoch 177, CIFAR-10 Batch 3:  cost: 0.00746628
# Accuracy: 0.6328
# Epoch 177, CIFAR-10 Batch 4:  cost: 0.0884516
# Accuracy: 0.6314
# Epoch 177, CIFAR-10 Batch 5:  cost: 0.00582679
# Accuracy: 0.6318
# Epoch 178, CIFAR-10 Batch 1:  cost: 0.0372768
# Accuracy: 0.6322
# Epoch 178, CIFAR-10 Batch 2:  cost: 0.00435627
# Accuracy: 0.626
# Epoch 178, CIFAR-10 Batch 3:  cost: 0.00674873
# Accuracy: 0.6292
# Epoch 178, CIFAR-10 Batch 4:  cost: 0.0871177
# Accuracy: 0.6382
# Epoch 178, CIFAR-10 Batch 5:  cost: 0.00482973
# Accuracy: 0.6294
# Epoch 179, CIFAR-10 Batch 1:  cost: 0.0495673
# Accuracy: 0.6334
# Epoch 179, CIFAR-10 Batch 2:  cost: 0.0125783
# Accuracy: 0.621
# Epoch 179, CIFAR-10 Batch 3:  cost: 0.00444506
# Accuracy: 0.626
# Epoch 179, CIFAR-10 Batch 4:  cost: 0.0889975
# Accuracy: 0.6284
# Epoch 179, CIFAR-10 Batch 5:  cost: 0.00531846
# Accuracy: 0.6304
# Epoch 180, CIFAR-10 Batch 1:  cost: 0.0374851
# Accuracy: 0.6306
# Epoch 180, CIFAR-10 Batch 2:  cost: 0.00557076
# Accuracy: 0.6302
# Epoch 180, CIFAR-10 Batch 3:  cost: 0.00720454
# Accuracy: 0.635
# Epoch 180, CIFAR-10 Batch 4:  cost: 0.091419
# Accuracy: 0.6294
# Epoch 180, CIFAR-10 Batch 5:  cost: 0.00487045
# Accuracy: 0.6372
# Epoch 181, CIFAR-10 Batch 1:  cost: 0.0188305
# Accuracy: 0.6344
# Epoch 181, CIFAR-10 Batch 2:  cost: 0.00624809
# Accuracy: 0.624
# Epoch 181, CIFAR-10 Batch 3:  cost: 0.00414563
# Accuracy: 0.6262
# Epoch 181, CIFAR-10 Batch 4:  cost: 0.0896065
# Accuracy: 0.633
# Epoch 181, CIFAR-10 Batch 5:  cost: 0.00392579
# Accuracy: 0.6348
# Epoch 182, CIFAR-10 Batch 1:  cost: 0.022295
# Accuracy: 0.6298
# Epoch 182, CIFAR-10 Batch 2:  cost: 0.00792767
# Accuracy: 0.6274
# Epoch 182, CIFAR-10 Batch 3:  cost: 0.00563356
# Accuracy: 0.6364
# Epoch 182, CIFAR-10 Batch 4:  cost: 0.0878896
# Accuracy: 0.631
# Epoch 182, CIFAR-10 Batch 5:  cost: 0.00447714
# Accuracy: 0.6308
# Epoch 183, CIFAR-10 Batch 1:  cost: 0.0224954
# Accuracy: 0.6278
# Epoch 183, CIFAR-10 Batch 2:  cost: 0.00595815
# Accuracy: 0.6312
# Epoch 183, CIFAR-10 Batch 3:  cost: 0.0054145
# Accuracy: 0.6294
# Epoch 183, CIFAR-10 Batch 4:  cost: 0.09207
# Accuracy: 0.6258
# Epoch 183, CIFAR-10 Batch 5:  cost: 0.00466801
# Accuracy: 0.6256
# Epoch 184, CIFAR-10 Batch 1:  cost: 0.0422275
# Accuracy: 0.629
# Epoch 184, CIFAR-10 Batch 2:  cost: 0.00381121
# Accuracy: 0.6266
# Epoch 184, CIFAR-10 Batch 3:  cost: 0.00302097
# Accuracy: 0.636
# Epoch 184, CIFAR-10 Batch 4:  cost: 0.0928513
# Accuracy: 0.6274
# Epoch 184, CIFAR-10 Batch 5:  cost: 0.0045563
# Accuracy: 0.629
# Epoch 185, CIFAR-10 Batch 1:  cost: 0.0361705
# Accuracy: 0.6344
# Epoch 185, CIFAR-10 Batch 2:  cost: 0.00504802
# Accuracy: 0.632
# Epoch 185, CIFAR-10 Batch 3:  cost: 0.00606784
# Accuracy: 0.6262
# Epoch 185, CIFAR-10 Batch 4:  cost: 0.0898329
# Accuracy: 0.6278
# Epoch 185, CIFAR-10 Batch 5:  cost: 0.00396902
# Accuracy: 0.6288
# Epoch 186, CIFAR-10 Batch 1:  cost: 0.0197156
# Accuracy: 0.641
# Epoch 186, CIFAR-10 Batch 2:  cost: 0.00238353
# Accuracy: 0.6342
# Epoch 186, CIFAR-10 Batch 3:  cost: 0.0270607
# Accuracy: 0.6414
# Epoch 186, CIFAR-10 Batch 4:  cost: 0.0905096
# Accuracy: 0.636
# Epoch 186, CIFAR-10 Batch 5:  cost: 0.00454535
# Accuracy: 0.637
# Epoch 187, CIFAR-10 Batch 1:  cost: 0.0225772
# Accuracy: 0.6286
# Epoch 187, CIFAR-10 Batch 2:  cost: 0.00217394
# Accuracy: 0.6294
# Epoch 187, CIFAR-10 Batch 3:  cost: 0.00417742
# Accuracy: 0.625
# Epoch 187, CIFAR-10 Batch 4:  cost: 0.0903766
# Accuracy: 0.627
# Epoch 187, CIFAR-10 Batch 5:  cost: 0.00410132
# Accuracy: 0.6242
# Epoch 188, CIFAR-10 Batch 1:  cost: 0.0310486
# Accuracy: 0.629
# Epoch 188, CIFAR-10 Batch 2:  cost: 0.0239958
# Accuracy: 0.6246
# Epoch 188, CIFAR-10 Batch 3:  cost: 0.00356703
# Accuracy: 0.6404
# Epoch 188, CIFAR-10 Batch 4:  cost: 0.0870152
# Accuracy: 0.63
# Epoch 188, CIFAR-10 Batch 5:  cost: 0.00806521
# Accuracy: 0.6324
# Epoch 189, CIFAR-10 Batch 1:  cost: 0.0179831
# Accuracy: 0.6282
# Epoch 189, CIFAR-10 Batch 2:  cost: 0.00322783
# Accuracy: 0.633
# Epoch 189, CIFAR-10 Batch 3:  cost: 0.00355364
# Accuracy: 0.6366
# Epoch 189, CIFAR-10 Batch 4:  cost: 0.0877081
# Accuracy: 0.6352
# Epoch 189, CIFAR-10 Batch 5:  cost: 0.0655025
# Accuracy: 0.6226
# Epoch 190, CIFAR-10 Batch 1:  cost: 0.0237281
# Accuracy: 0.6358
# Epoch 190, CIFAR-10 Batch 2:  cost: 0.00360038
# Accuracy: 0.6304
# Epoch 190, CIFAR-10 Batch 3:  cost: 0.014893
# Accuracy: 0.636
# Epoch 190, CIFAR-10 Batch 4:  cost: 0.089225
# Accuracy: 0.627
# Epoch 190, CIFAR-10 Batch 5:  cost: 0.00385976
# Accuracy: 0.6286
# Epoch 191, CIFAR-10 Batch 1:  cost: 0.0768553
# Accuracy: 0.6292
# Epoch 191, CIFAR-10 Batch 2:  cost: 0.00930332
# Accuracy: 0.6278
# Epoch 191, CIFAR-10 Batch 3:  cost: 0.0037184
# Accuracy: 0.6284
# Epoch 191, CIFAR-10 Batch 4:  cost: 0.0915363
# Accuracy: 0.622
# Epoch 191, CIFAR-10 Batch 5:  cost: 0.0188395
# Accuracy: 0.6288
# Epoch 192, CIFAR-10 Batch 1:  cost: 0.0442017
# Accuracy: 0.6382
# Epoch 192, CIFAR-10 Batch 2:  cost: 0.00827783
# Accuracy: 0.6364
# Epoch 192, CIFAR-10 Batch 3:  cost: 0.00662033
# Accuracy: 0.634
# Epoch 192, CIFAR-10 Batch 4:  cost: 0.118922
# Accuracy: 0.6226
# Epoch 192, CIFAR-10 Batch 5:  cost: 0.00413368
# Accuracy: 0.6292
# Epoch 193, CIFAR-10 Batch 1:  cost: 0.0358326
# Accuracy: 0.631
# Epoch 193, CIFAR-10 Batch 2:  cost: 0.0052709
# Accuracy: 0.6284
# Epoch 193, CIFAR-10 Batch 3:  cost: 0.00413075
# Accuracy: 0.6312
# Epoch 193, CIFAR-10 Batch 4:  cost: 0.0824844
# Accuracy: 0.6296
# Epoch 193, CIFAR-10 Batch 5:  cost: 0.0145474
# Accuracy: 0.6342
# Epoch 194, CIFAR-10 Batch 1:  cost: 0.0179856
# Accuracy: 0.6252
# Epoch 194, CIFAR-10 Batch 2:  cost: 0.00394364
# Accuracy: 0.6332
# Epoch 194, CIFAR-10 Batch 3:  cost: 0.00409462
# Accuracy: 0.6348
# Epoch 194, CIFAR-10 Batch 4:  cost: 0.0924846
# Accuracy: 0.6282
# Epoch 194, CIFAR-10 Batch 5:  cost: 0.0199714
# Accuracy: 0.6336
# Epoch 195, CIFAR-10 Batch 1:  cost: 0.0187021
# Accuracy: 0.633
# Epoch 195, CIFAR-10 Batch 2:  cost: 0.00360137
# Accuracy: 0.6266
# Epoch 195, CIFAR-10 Batch 3:  cost: 0.0068586
# Accuracy: 0.6288
# Epoch 195, CIFAR-10 Batch 4:  cost: 0.0849098
# Accuracy: 0.6274
# Epoch 195, CIFAR-10 Batch 5:  cost: 0.00532321
# Accuracy: 0.6324
# Epoch 196, CIFAR-10 Batch 1:  cost: 0.0335197
# Accuracy: 0.631
# Epoch 196, CIFAR-10 Batch 2:  cost: 0.00582757
# Accuracy: 0.6312
# Epoch 196, CIFAR-10 Batch 3:  cost: 0.00356315
# Accuracy: 0.6258
# Epoch 196, CIFAR-10 Batch 4:  cost: 0.0878327
# Accuracy: 0.6238
# Epoch 196, CIFAR-10 Batch 5:  cost: 0.00485777
# Accuracy: 0.6316
# Epoch 197, CIFAR-10 Batch 1:  cost: 0.0305197
# Accuracy: 0.6268
# Epoch 197, CIFAR-10 Batch 2:  cost: 0.00643631
# Accuracy: 0.6342
# Epoch 197, CIFAR-10 Batch 3:  cost: 0.00626047
# Accuracy: 0.6306
# Epoch 197, CIFAR-10 Batch 4:  cost: 0.0844037
# Accuracy: 0.626
# Epoch 197, CIFAR-10 Batch 5:  cost: 0.00409286
# Accuracy: 0.6264
# Epoch 198, CIFAR-10 Batch 1:  cost: 0.0256777
# Accuracy: 0.6346
# Epoch 198, CIFAR-10 Batch 2:  cost: 0.00471909
# Accuracy: 0.6246
# Epoch 198, CIFAR-10 Batch 3:  cost: 0.00364632
# Accuracy: 0.6412
# Epoch 198, CIFAR-10 Batch 4:  cost: 0.083129
# Accuracy: 0.6322
# Epoch 198, CIFAR-10 Batch 5:  cost: 0.0035677
# Accuracy: 0.637
# Epoch 199, CIFAR-10 Batch 1:  cost: 0.0198799
# Accuracy: 0.6372
# Epoch 199, CIFAR-10 Batch 2:  cost: 0.00186931
# Accuracy: 0.6386
# Epoch 199, CIFAR-10 Batch 3:  cost: 0.00544601
# Accuracy: 0.633
# Epoch 199, CIFAR-10 Batch 4:  cost: 0.0865161
# Accuracy: 0.6298
# Epoch 199, CIFAR-10 Batch 5:  cost: 0.00517204
# Accuracy: 0.6288
# Epoch 200, CIFAR-10 Batch 1:  cost: 0.0497865
# Accuracy: 0.6274
# Epoch 200, CIFAR-10 Batch 2:  cost: 0.00200065
# Accuracy: 0.626
# Epoch 200, CIFAR-10 Batch 3:  cost: 0.00228042
# Accuracy: 0.6298
# Epoch 200, CIFAR-10 Batch 4:  cost: 0.0872909
# Accuracy: 0.6264
# Epoch 200, CIFAR-10 Batch 5:  cost: 0.00443987
# Accuracy: 0.6292

# %% [markdown]
# # 检查点
#
# 模型已保存到本地。
#
# ## 测试模型
#
# 利用测试数据集测试你的模型。这将是最终的准确率。你的准确率应该高于 50%。如果没达到，请继续调整模型结构和参数。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.6244028662420382

# %% [markdown]
# ## 为何准确率只有50-80%？
#
# 你可能想问，为何准确率不能更高了？首先，对于简单的 CNN 网络来说，50% 已经不低了。纯粹猜测的准确率为10%。但是，你可能注意到有人的准确率[远远超过 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130)。这是因为我们还没有介绍所有的神经网络知识。我们还需要掌握一些其他技巧。
#
# ## 提交项目
#
# 提交项目时，确保先运行所有单元，然后再保存记事本。将 notebook 文件另存为“dlnd_image_classification.ipynb”，再在目录 "File" -> "Download as" 另存为 HTML 格式。请在提交的项目中包含 “helper.py” 和 “problem_unittests.py” 文件。
